# %% [markdown]
# # Financial Data Analysis with Python - a Deep Dive

# %% [markdown]
# ## Installing required Libraries/Packages

# %% [markdown]
# Install yfinance with:
# - pip install yfinance

# %% [markdown]
# (first: conda update anaconda)

# %%
# !pip install yfinance

# %% [markdown]
# ## Loading Financial Data from the Web

# %%
import pandas as pd
import yfinance as yf

# %%
start = "2014-10-01"
end = "2021-05-31"

# %%
symbol = "BA"

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-10-01  127.370003  127.370003  124.309998  124.669998  108.406654
# 2014-10-02  124.400002  125.550003  123.839996  124.169998  107.971901
# 2014-10-03  124.660004  126.870003  124.660004  126.360001  109.876213
# 2014-10-06  127.089996  127.190002  125.379997  126.260002  109.789246
# 2014-10-07  125.519997  125.519997  123.290001  123.320000  107.232765
# ...                ...         ...         ...         ...         ...
# 2021-05-24  235.139999  238.500000  232.600006  237.440002  237.440002
# 2021-05-25  240.000000  243.779999  239.229996  240.740005  240.740005
# 2021-05-26  241.699997  242.490005  239.869995  241.369995  241.369995
# 2021-05-27  248.110001  252.600006  247.190002  250.699997  250.699997
# 2021-05-28  247.479996  248.979996  245.369995  247.020004  247.020004
#
#               Volume
# Date
# 2014-10-01   5265200
# 2014-10-02   3204500
# 2014-10-03   3075900
# 2014-10-06   2681000
# 2014-10-07   3554900
# ...              ...
# 2021-05-24  10106000
# 2021-05-25  12908000
# 2021-05-26   7240200
# 2021-05-27  18404400
# 2021-05-28  11197400
#
# [1677 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1677 entries, 2014-10-01 to 2021-05-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1677 non-null   float64
#  1   High       1677 non-null   float64
#  2   Low        1677 non-null   float64
#  3   Close      1677 non-null   float64
#  4   Adj Close  1677 non-null   float64
#  5   Volume     1677 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 91.7 KB

# %%
symbol = ["BA", "MSFT", "^DJI", "EURUSD=X", "GC=F", "BTC-USD"]

# %% [markdown]
# Ticker Symbols: <br>
# - __BA__: Boeing (US Stock)
# - __MSFT__: Microsoft Corp (US Stock)
# - __^DJI__: Dow Jones Industrial Average (US Stock Index)
# - __EURUSD=X__: Exchange Rate for Currency Pair EUR/USD (Forex)
# - __GC=F__: Gold Price (Precious Metal / Commodity)
# - __BTC-USD__: Bitcoin in USD (Cryptocurrency)

# %%
df = yf.download(symbol, start, end)
df.head()
# Out:
# [*********************100%%**********************]  6 of 6 completed
#              Adj Close                                                \
#                     BA     BTC-USD  EURUSD=X         GC=F       MSFT
# Date
# 2014-10-01  108.406670  383.614990  1.262834  1214.599976  39.539959
# 2014-10-02  107.971893  375.071991  1.262419  1214.199951  39.419342
# 2014-10-03  109.876198  359.511993  1.267058  1192.199951  39.703625
# 2014-10-04         NaN  328.865997       NaN          NaN        NaN
# 2014-10-05         NaN  320.510010       NaN          NaN        NaN
#
#                                Close                                     ...  \
#                     ^DJI          BA     BTC-USD  EURUSD=X         GC=F  ...
# Date                                                                     ...
# 2014-10-01  16804.710938  124.669998  383.614990  1.262834  1214.599976  ...
# 2014-10-02  16801.050781  124.169998  375.071991  1.262419  1214.199951  ...
# 2014-10-03  17009.689453  126.360001  359.511993  1.267058  1192.199951  ...
# 2014-10-04           NaN         NaN  328.865997       NaN          NaN  ...
# 2014-10-05           NaN         NaN  320.510010       NaN          NaN  ...
#
#                 Open                                           Volume  \
#             EURUSD=X         GC=F       MSFT          ^DJI         BA
# Date
# 2014-10-01  1.262913  1207.699951  46.270000  17040.460938  5265200.0
# 2014-10-02  1.262499  1215.300049  45.830002  16808.269531  3204500.0
# 2014-10-03  1.266994  1212.400024  45.980000  16802.199219  3075900.0
# 2014-10-04       NaN          NaN        NaN           NaN        NaN
# 2014-10-05       NaN          NaN        NaN           NaN        NaN
#
#
#              BTC-USD EURUSD=X   GC=F        MSFT         ^DJI
# Date
# 2014-10-01  26229400      0.0  178.0  38088400.0  104240000.0
# 2014-10-02  21777700      0.0  176.0  25119400.0   75490000.0
# 2014-10-03  30901200      0.0  499.0  32453200.0   87940000.0
# 2014-10-04  47236500      NaN    NaN         NaN          NaN
# 2014-10-05  83308096      NaN    NaN         NaN          NaN
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Freq: D
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        1677 non-null   float64
#  1   (Adj Close, BTC-USD)   2434 non-null   float64
#  2   (Adj Close, EURUSD=X)  1735 non-null   float64
#  3   (Adj Close, GC=F)      1674 non-null   float64
#  4   (Adj Close, MSFT)      1677 non-null   float64
#  5   (Adj Close, ^DJI)      1677 non-null   float64
#  6   (Close, BA)            1677 non-null   float64
#  7   (Close, BTC-USD)       2434 non-null   float64
#  8   (Close, EURUSD=X)      1735 non-null   float64
#  9   (Close, GC=F)          1674 non-null   float64
#  10  (Close, MSFT)          1677 non-null   float64
#  11  (Close, ^DJI)          1677 non-null   float64
#  12  (High, BA)             1677 non-null   float64
#  13  (High, BTC-USD)        2434 non-null   float64
#  14  (High, EURUSD=X)       1735 non-null   float64
#  15  (High, GC=F)           1674 non-null   float64
#  16  (High, MSFT)           1677 non-null   float64
#  17  (High, ^DJI)           1677 non-null   float64
#  18  (Low, BA)              1677 non-null   float64
#  19  (Low, BTC-USD)         2434 non-null   float64
#  20  (Low, EURUSD=X)        1735 non-null   float64
#  21  (Low, GC=F)            1674 non-null   float64
#  22  (Low, MSFT)            1677 non-null   float64
#  23  (Low, ^DJI)            1677 non-null   float64
#  24  (Open, BA)             1677 non-null   float64
#  25  (Open, BTC-USD)        2434 non-null   float64
#  26  (Open, EURUSD=X)       1735 non-null   float64
#  27  (Open, GC=F)           1674 non-null   float64
#  28  (Open, MSFT)           1677 non-null   float64
#  29  (Open, ^DJI)           1677 non-null   float64
#  30  (Volume, BA)           1677 non-null   float64
#  31  (Volume, BTC-USD)      2434 non-null   int64
#  32  (Volume, EURUSD=X)     1735 non-null   float64
#  33  (Volume, GC=F)         1674 non-null   float64
#  34  (Volume, MSFT)         1677 non-null   float64
#  35  (Volume, ^DJI)         1677 non-null   float64
# dtypes: float64(35), int64(1)
# memory usage: 703.6 KB

# %%
df.to_csv("multi_assets.csv")

# %% [markdown]
# ## Initial Inspection and Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
#plt.style.use("seaborn-v0_8")

# %%
df = pd.read_csv("multi_assets.csv", 
header = [0, 1], # first and second column be colum header
index_col = 0, # the column of the index (the date)
parse_dates = [0])

df
# Out:
#            Adj Close                                                    \
#                   BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01  108.4067   383.6150   1.2628 1214.6000  39.5400 16804.7109
# 2014-10-02  107.9719   375.0720   1.2624 1214.2000  39.4193 16801.0508
# 2014-10-03  109.8762   359.5120   1.2671 1192.2000  39.7036 17009.6895
# 2014-10-04       NaN   328.8660      NaN       NaN      NaN        NaN
# 2014-10-05       NaN   320.5100      NaN       NaN      NaN        NaN
# ...              ...        ...      ...       ...      ...        ...
# 2021-05-26  241.3700 39294.1992   1.2249 1901.3000 246.5429 34323.0508
# 2021-05-27  250.7000 38436.9688   1.2193 1895.7000 244.4058 34464.6406
# 2021-05-28  247.0200 35697.6055   1.2193 1902.5000 244.7685 34529.4492
# 2021-05-29       NaN 34616.0664      NaN       NaN      NaN        NaN
# 2021-05-30       NaN 35678.1289      NaN       NaN      NaN        NaN
#
#               Close                                ...     Open            \
#                  BA    BTC-USD EURUSD=X      GC=F  ... EURUSD=X      GC=F
# Date                                               ...
# 2014-10-01 124.6700   383.6150   1.2628 1214.6000  ...   1.2629 1207.7000
# 2014-10-02 124.1700   375.0720   1.2624 1214.2000  ...   1.2625 1215.3000
# 2014-10-03 126.3600   359.5120   1.2671 1192.2000  ...   1.2670 1212.4000
# 2014-10-04      NaN   328.8660      NaN       NaN  ...      NaN       NaN
# 2014-10-05      NaN   320.5100      NaN       NaN  ...      NaN       NaN
# ...             ...        ...      ...       ...  ...      ...       ...
# 2021-05-26 241.3700 39294.1992   1.2249 1901.3000  ...   1.2249 1901.3000
# 2021-05-27 250.7000 38436.9688   1.2193 1895.7000  ...   1.2190 1896.8000
# 2021-05-28 247.0200 35697.6055   1.2193 1902.5000  ...   1.2193 1897.5000
# 2021-05-29      NaN 34616.0664      NaN       NaN  ...      NaN       NaN
# 2021-05-30      NaN 35678.1289      NaN       NaN  ...      NaN       NaN
#
#                                       Volume                        \
#                MSFT       ^DJI            BA      BTC-USD EURUSD=X
# Date
# 2014-10-01  46.2700 17040.4609  5265200.0000     26229400   0.0000
# 2014-10-02  45.8300 16808.2695  3204500.0000     21777700   0.0000
# 2014-10-03  45.9800 16802.1992  3075900.0000     30901200   0.0000
# 2014-10-04      NaN        NaN           NaN     47236500      NaN
# 2014-10-05      NaN        NaN           NaN     83308096      NaN
# ...             ...        ...           ...          ...      ...
# 2021-05-26 251.4300 34336.3398  7240200.0000  51346735160   0.0000
# 2021-05-27 251.1700 34432.4688 18404400.0000  43210968721   0.0000
# 2021-05-28 251.0000 34558.5000 11197400.0000  55200191952   0.0000
# 2021-05-29      NaN        NaN           NaN  45231013335      NaN
# 2021-05-30      NaN        NaN           NaN  31646080921      NaN
#
#
#                   GC=F          MSFT           ^DJI
# Date
# 2014-10-01    178.0000 38088400.0000 104240000.0000
# 2014-10-02    176.0000 25119400.0000  75490000.0000
# 2014-10-03    499.0000 32453200.0000  87940000.0000
# 2014-10-04         NaN           NaN            NaN
# 2014-10-05         NaN           NaN            NaN
# ...                ...           ...            ...
# 2021-05-26 170526.0000 17771600.0000 258780000.0000
# 2021-05-27  35794.0000 24426200.0000 520630000.0000
# 2021-05-28   2415.0000 18270200.0000 290850000.0000
# 2021-05-29         NaN           NaN            NaN
# 2021-05-30         NaN           NaN            NaN
#
# [2434 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        1677 non-null   float64
#  1   (Adj Close, BTC-USD)   2434 non-null   float64
#  2   (Adj Close, EURUSD=X)  1735 non-null   float64
#  3   (Adj Close, GC=F)      1674 non-null   float64
#  4   (Adj Close, MSFT)      1677 non-null   float64
#  5   (Adj Close, ^DJI)      1677 non-null   float64
#  6   (Close, BA)            1677 non-null   float64
#  7   (Close, BTC-USD)       2434 non-null   float64
#  8   (Close, EURUSD=X)      1735 non-null   float64
#  9   (Close, GC=F)          1674 non-null   float64
#  10  (Close, MSFT)          1677 non-null   float64
#  11  (Close, ^DJI)          1677 non-null   float64
#  12  (High, BA)             1677 non-null   float64
#  13  (High, BTC-USD)        2434 non-null   float64
#  14  (High, EURUSD=X)       1735 non-null   float64
#  15  (High, GC=F)           1674 non-null   float64
#  16  (High, MSFT)           1677 non-null   float64
#  17  (High, ^DJI)           1677 non-null   float64
#  18  (Low, BA)              1677 non-null   float64
#  19  (Low, BTC-USD)         2434 non-null   float64
#  20  (Low, EURUSD=X)        1735 non-null   float64
#  21  (Low, GC=F)            1674 non-null   float64
#  22  (Low, MSFT)            1677 non-null   float64
#  23  (Low, ^DJI)            1677 non-null   float64
#  24  (Open, BA)             1677 non-null   float64
#  25  (Open, BTC-USD)        2434 non-null   float64
#  26  (Open, EURUSD=X)       1735 non-null   float64
#  27  (Open, GC=F)           1674 non-null   float64
#  28  (Open, MSFT)           1677 non-null   float64
#  29  (Open, ^DJI)           1677 non-null   float64
#  30  (Volume, BA)           1677 non-null   float64
#  31  (Volume, BTC-USD)      2434 non-null   int64
#  32  (Volume, EURUSD=X)     1735 non-null   float64
#  33  (Volume, GC=F)         1674 non-null   float64
#  34  (Volume, MSFT)         1677 non-null   float64
#  35  (Volume, ^DJI)         1677 non-null   float64
# dtypes: float64(35), int64(1)
# memory usage: 703.6 KB

# %%
df.Close # outer index level
# Selecting the close price of the stocks
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 124.6700   383.6150    1.2628 1214.6000  45.9000 16804.7109
# 2014-10-02 124.1700   375.0720    1.2624 1214.2000  45.7600 16801.0508
# 2014-10-03 126.3600   359.5120    1.2671 1192.2000  46.0900 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 251.4900 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 249.3100 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 249.6800 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
df.Close.BA # one column (1)
# Out:
# Date
# 2014-10-01   124.6700
# 2014-10-02   124.1700
# 2014-10-03   126.3600
# 2014-10-04        NaN
# 2014-10-05        NaN
#                ...
# 2021-05-26   241.3700
# 2021-05-27   250.7000
# 2021-05-28   247.0200
# 2021-05-29        NaN
# 2021-05-30        NaN
# Name: BA, Length: 2434, dtype: float64

# %%
df.loc[:, ("Close", "BA")] # one column (2)
# Out:
# Date
# 2014-10-01   124.6700
# 2014-10-02   124.1700
# 2014-10-03   126.3600
# 2014-10-04        NaN
# 2014-10-05        NaN
#                ...
# 2021-05-26   241.3700
# 2021-05-27   250.7000
# 2021-05-28   247.0200
# 2021-05-29        NaN
# 2021-05-30        NaN
# Name: (Close, BA), Length: 2434, dtype: float64

# %%
# All the data that correspons to this date.
df.loc["2015-01-07"] # one row
# Out:
# Adj Close  BA              113.2724
#            BTC-USD         294.3370
#            EURUSD=X          1.1875
#            GC=F           1210.6000
#            MSFT             40.0754
#            ^DJI          17584.5195
# Close      BA              129.5100
#            BTC-USD         294.3370
#            EURUSD=X          1.1875
#            GC=F           1210.6000
#            MSFT             46.2300
#            ^DJI          17584.5195
# High       BA              129.9700
#            BTC-USD         298.7540
#            EURUSD=X          1.1900
#            GC=F           1219.2000
#            MSFT             46.4600
#            ^DJI          17597.0801
# Low        BA              128.7200
#            BTC-USD         283.0790
#            EURUSD=X          1.1804
#            GC=F           1210.6000
#            MSFT             45.4900
#            ^DJI          17374.7793
# Open       BA              128.7400
#            BTC-USD         286.0770
#            EURUSD=X          1.1875
#            GC=F           1219.2000
#            MSFT             45.9800
#            ^DJI          17374.7793
# Volume     BA          3573200.0000
#            BTC-USD    24866800.0000
#            EURUSD=X          0.0000
#            GC=F             29.0000
#            MSFT       29114100.0000
#            ^DJI       91030000.0000
# Name: 2015-01-07 00:00:00, dtype: float64

# %%
df.loc["2015"] # one year (all the data of 2015)
# Out:
#            Adj Close                                                   Close  \
#                   BA  BTC-USD EURUSD=X      GC=F    MSFT       ^DJI       BA
# Date
# 2015-01-01       NaN 314.2490   1.2099       NaN     NaN        NaN      NaN
# 2015-01-02  113.6572 315.0320   1.2089 1186.0000 40.5348 17832.9902 129.9500
# 2015-01-03       NaN 281.0820      NaN       NaN     NaN        NaN      NaN
# 2015-01-04       NaN 264.1950      NaN       NaN     NaN        NaN      NaN
# 2015-01-05  112.8701 274.4740   1.1946 1203.9000 40.1621 17501.6504 129.0500
# ...              ...      ...      ...       ...     ...        ...      ...
# 2015-12-27       NaN 422.8230      NaN       NaN     NaN        NaN      NaN
# 2015-12-28  129.6283 422.2790   1.0966 1070.5000 49.8218 17528.2695 144.5400
# 2015-12-29  132.1484 432.9830   1.0975 1077.5000 50.3560 17720.9805 147.3500
# 2015-12-30  131.3054 426.6200   1.0928 1060.1000 50.1423 17603.8691 146.4100
# 2015-12-31  129.6731 430.5670   1.0934 1060.3000 49.4032 17425.0293 144.5900
#
#                                         ...     Open                    \
#             BTC-USD EURUSD=X      GC=F  ... EURUSD=X      GC=F    MSFT
# Date                                    ...
# 2015-01-01 314.2490   1.2099       NaN  ...   1.2099       NaN     NaN
# 2015-01-02 315.0320   1.2089 1186.0000  ...   1.2089 1184.0000 46.6600
# 2015-01-03 281.0820      NaN       NaN  ...      NaN       NaN     NaN
# 2015-01-04 264.1950      NaN       NaN  ...      NaN       NaN     NaN
# 2015-01-05 274.4740   1.1946 1203.9000  ...   1.1955 1180.3000 46.3700
# ...             ...      ...       ...  ...      ...       ...     ...
# 2015-12-27 422.8230      NaN       NaN  ...      NaN       NaN     NaN
# 2015-12-28 422.2790   1.0966 1070.5000  ...   1.0966 1077.9000 55.3500
# 2015-12-29 432.9830   1.0975 1077.5000  ...   1.0977 1079.1000 56.2900
# 2015-12-30 426.6200   1.0928 1060.1000  ...   1.0928 1068.6000 56.4700
# 2015-12-31 430.5670   1.0934 1060.3000  ...   1.0938 1061.9000 56.0400
#
#                             Volume                                            \
#                  ^DJI           BA   BTC-USD EURUSD=X     GC=F          MSFT
# Date
# 2015-01-01        NaN          NaN   8036550   0.0000      NaN           NaN
# 2015-01-02 17823.0703 4294200.0000   7860650   0.0000 138.0000 27913900.0000
# 2015-01-03        NaN          NaN  33054400      NaN      NaN           NaN
# 2015-01-04        NaN          NaN  55629100      NaN      NaN           NaN
# 2015-01-05 17821.3008 5024800.0000  43962800   0.0000 470.0000 39673900.0000
# ...               ...          ...       ...      ...      ...           ...
# 2015-12-27        NaN          NaN  53591200      NaN      NaN           NaN
# 2015-12-28 17535.6602 1980000.0000  49638600   0.0000 361.0000 22458300.0000
# 2015-12-29 17547.3691 3133600.0000  51596500   0.0000 252.0000 27731400.0000
# 2015-12-30 17711.9395 1619000.0000  46889400   0.0000  71.0000 21704500.0000
# 2015-12-31 17590.6602 2105200.0000  45996600   0.0000  10.0000 27334100.0000
#
#
#                      ^DJI
# Date
# 2015-01-01            NaN
# 2015-01-02  76270000.0000
# 2015-01-03            NaN
# 2015-01-04            NaN
# 2015-01-05 116160000.0000
# ...                   ...
# 2015-12-27            NaN
# 2015-12-28  59770000.0000
# 2015-12-29  69860000.0000
# 2015-12-30  59760000.0000
# 2015-12-31  93690000.0000
#
# [365 rows x 36 columns]

# %%
df.loc["2020-06":, ("Close", "BA")] # one month for one column
# from 2020-06 to the end, give the close price of BA.
# Out:
# Date
# 2020-06-01   151.3900
# 2020-06-02   153.3100
# 2020-06-03   173.1600
# 2020-06-04   184.3000
# 2020-06-05   205.4300
#                ...
# 2021-05-26   241.3700
# 2021-05-27   250.7000
# 2021-05-28   247.0200
# 2021-05-29        NaN
# 2021-05-30        NaN
# Name: (Close, BA), Length: 364, dtype: float64

# %%
# swap outer and inner index
df = df.swaplevel(axis = "columns").sort_index(axis = "columns")
df
# Out:
#                   BA                                                    \
#            Adj Close    Close     High      Low     Open        Volume
# Date
# 2014-10-01  108.4067 124.6700 127.3700 124.3100 127.3700  5265200.0000
# 2014-10-02  107.9719 124.1700 125.5500 123.8400 124.4000  3204500.0000
# 2014-10-03  109.8762 126.3600 126.8700 124.6600 124.6600  3075900.0000
# 2014-10-04       NaN      NaN      NaN      NaN      NaN           NaN
# 2014-10-05       NaN      NaN      NaN      NaN      NaN           NaN
# ...              ...      ...      ...      ...      ...           ...
# 2021-05-26  241.3700 241.3700 242.4900 239.8700 241.7000  7240200.0000
# 2021-05-27  250.7000 250.7000 252.6000 247.1900 248.1100 18404400.0000
# 2021-05-28  247.0200 247.0200 248.9800 245.3700 247.4800 11197400.0000
# 2021-05-29       NaN      NaN      NaN      NaN      NaN           NaN
# 2021-05-30       NaN      NaN      NaN      NaN      NaN           NaN
#
#               BTC-USD                                   ...     MSFT           \
#             Adj Close      Close       High        Low  ...     High      Low
# Date                                                    ...
# 2014-10-01   383.6150   383.6150   391.3790   380.7800  ...  46.5300  45.8500
# 2014-10-02   375.0720   375.0720   385.4970   372.9460  ...  46.1000  45.6400
# 2014-10-03   359.5120   359.5120   377.6950   357.8590  ...  46.3000  45.6100
# 2014-10-04   328.8660   328.8660   364.4870   325.8860  ...      NaN      NaN
# 2014-10-05   320.5100   320.5100   341.8010   289.2960  ...      NaN      NaN
# ...               ...        ...        ...        ...  ...      ...      ...
# 2021-05-26 39294.1992 39294.1992 40782.0781 37905.8359  ... 252.9400 250.7500
# 2021-05-27 38436.9688 38436.9688 40379.6172 37247.9023  ... 251.4800 249.2500
# 2021-05-28 35697.6055 35697.6055 38856.9688 34779.0391  ... 252.0800 249.5600
# 2021-05-29 34616.0664 34616.0664 37234.5000 33693.9297  ...      NaN      NaN
# 2021-05-30 35678.1289 35678.1289 36400.6680 33520.7383  ...      NaN      NaN
#
#                                         ^DJI                                   \
#                Open        Volume  Adj Close      Close       High        Low
# Date
# 2014-10-01  46.2700 38088400.0000 16804.7109 16804.7109 17041.1602 16776.1309
# 2014-10-02  45.8300 25119400.0000 16801.0508 16801.0508 16857.2500 16674.0391
# 2014-10-03  45.9800 32453200.0000 17009.6895 17009.6895 17027.8398 16802.1992
# 2014-10-04      NaN           NaN        NaN        NaN        NaN        NaN
# 2014-10-05      NaN           NaN        NaN        NaN        NaN        NaN
# ...             ...           ...        ...        ...        ...        ...
# 2021-05-26 251.4300 17771600.0000 34323.0508 34323.0508 34409.5898 34271.4414
# 2021-05-27 251.1700 24426200.0000 34464.6406 34464.6406 34608.8203 34389.2383
# 2021-05-28 251.0000 18270200.0000 34529.4492 34529.4492 34631.1094 34520.0898
# 2021-05-29      NaN           NaN        NaN        NaN        NaN        NaN
# 2021-05-30      NaN           NaN        NaN        NaN        NaN        NaN
#
#
#                  Open         Volume
# Date
# 2014-10-01 17040.4609 104240000.0000
# 2014-10-02 16808.2695  75490000.0000
# 2014-10-03 16802.1992  87940000.0000
# 2014-10-04        NaN            NaN
# 2014-10-05        NaN            NaN
# ...               ...            ...
# 2021-05-26 34336.3398 258780000.0000
# 2021-05-27 34432.4688 520630000.0000
# 2021-05-28 34558.5000 290850000.0000
# 2021-05-29        NaN            NaN
# 2021-05-30        NaN            NaN
#
# [2434 rows x 36 columns]

# %%
# Give me all the data of `EURUSD=X` stock entity.
df["EURUSD=X"]
# Out:
#             Adj Close  Close   High    Low   Open  Volume
# Date
# 2014-10-01     1.2628 1.2628 1.2640 1.2586 1.2629  0.0000
# 2014-10-02     1.2624 1.2624 1.2691 1.2616 1.2625  0.0000
# 2014-10-03     1.2671 1.2671 1.2670 1.2502 1.2670  0.0000
# 2014-10-04        NaN    NaN    NaN    NaN    NaN     NaN
# 2014-10-05        NaN    NaN    NaN    NaN    NaN     NaN
# ...               ...    ...    ...    ...    ...     ...
# 2021-05-26     1.2249 1.2249 1.2265 1.2200 1.2249  0.0000
# 2021-05-27     1.2193 1.2193 1.2217 1.2176 1.2190  0.0000
# 2021-05-28     1.2193 1.2193 1.2201 1.2133 1.2193  0.0000
# 2021-05-29        NaN    NaN    NaN    NaN    NaN     NaN
# 2021-05-30        NaN    NaN    NaN    NaN    NaN     NaN
#
# [2434 rows x 6 columns]

# %%
# Give me the data of bitcoin usd
df["BTC-USD"]
# Out:
#             Adj Close      Close       High        Low       Open       Volume
# Date
# 2014-10-01   383.6150   383.6150   391.3790   380.7800   387.4270     26229400
# 2014-10-02   375.0720   375.0720   385.4970   372.9460   383.9880     21777700
# 2014-10-03   359.5120   359.5120   377.6950   357.8590   375.1810     30901200
# 2014-10-04   328.8660   328.8660   364.4870   325.8860   359.8920     47236500
# 2014-10-05   320.5100   320.5100   341.8010   289.2960   328.9160     83308096
# ...               ...        ...        ...        ...        ...          ...
# 2021-05-26 39294.1992 39294.1992 40782.0781 37905.8359 38392.6250  51346735160
# 2021-05-27 38436.9688 38436.9688 40379.6172 37247.9023 39316.8906  43210968721
# 2021-05-28 35697.6055 35697.6055 38856.9688 34779.0391 38507.0820  55200191952
# 2021-05-29 34616.0664 34616.0664 37234.5000 33693.9297 35684.1562  45231013335
# 2021-05-30 35678.1289 35678.1289 36400.6680 33520.7383 34607.4062  31646080921
#
# [2434 rows x 6 columns]

# %%
# Swap back. 
# swap outer and inner index.
df = df.swaplevel(axis = "columns").sort_index(axis = "columns") 
df
# Out:
#            Adj Close                                                    \
#                   BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01  108.4067   383.6150   1.2628 1214.6000  39.5400 16804.7109
# 2014-10-02  107.9719   375.0720   1.2624 1214.2000  39.4193 16801.0508
# 2014-10-03  109.8762   359.5120   1.2671 1192.2000  39.7036 17009.6895
# 2014-10-04       NaN   328.8660      NaN       NaN      NaN        NaN
# 2014-10-05       NaN   320.5100      NaN       NaN      NaN        NaN
# ...              ...        ...      ...       ...      ...        ...
# 2021-05-26  241.3700 39294.1992   1.2249 1901.3000 246.5429 34323.0508
# 2021-05-27  250.7000 38436.9688   1.2193 1895.7000 244.4058 34464.6406
# 2021-05-28  247.0200 35697.6055   1.2193 1902.5000 244.7685 34529.4492
# 2021-05-29       NaN 34616.0664      NaN       NaN      NaN        NaN
# 2021-05-30       NaN 35678.1289      NaN       NaN      NaN        NaN
#
#               Close                                ...     Open            \
#                  BA    BTC-USD EURUSD=X      GC=F  ... EURUSD=X      GC=F
# Date                                               ...
# 2014-10-01 124.6700   383.6150   1.2628 1214.6000  ...   1.2629 1207.7000
# 2014-10-02 124.1700   375.0720   1.2624 1214.2000  ...   1.2625 1215.3000
# 2014-10-03 126.3600   359.5120   1.2671 1192.2000  ...   1.2670 1212.4000
# 2014-10-04      NaN   328.8660      NaN       NaN  ...      NaN       NaN
# 2014-10-05      NaN   320.5100      NaN       NaN  ...      NaN       NaN
# ...             ...        ...      ...       ...  ...      ...       ...
# 2021-05-26 241.3700 39294.1992   1.2249 1901.3000  ...   1.2249 1901.3000
# 2021-05-27 250.7000 38436.9688   1.2193 1895.7000  ...   1.2190 1896.8000
# 2021-05-28 247.0200 35697.6055   1.2193 1902.5000  ...   1.2193 1897.5000
# 2021-05-29      NaN 34616.0664      NaN       NaN  ...      NaN       NaN
# 2021-05-30      NaN 35678.1289      NaN       NaN  ...      NaN       NaN
#
#                                       Volume                        \
#                MSFT       ^DJI            BA      BTC-USD EURUSD=X
# Date
# 2014-10-01  46.2700 17040.4609  5265200.0000     26229400   0.0000
# 2014-10-02  45.8300 16808.2695  3204500.0000     21777700   0.0000
# 2014-10-03  45.9800 16802.1992  3075900.0000     30901200   0.0000
# 2014-10-04      NaN        NaN           NaN     47236500      NaN
# 2014-10-05      NaN        NaN           NaN     83308096      NaN
# ...             ...        ...           ...          ...      ...
# 2021-05-26 251.4300 34336.3398  7240200.0000  51346735160   0.0000
# 2021-05-27 251.1700 34432.4688 18404400.0000  43210968721   0.0000
# 2021-05-28 251.0000 34558.5000 11197400.0000  55200191952   0.0000
# 2021-05-29      NaN        NaN           NaN  45231013335      NaN
# 2021-05-30      NaN        NaN           NaN  31646080921      NaN
#
#
#                   GC=F          MSFT           ^DJI
# Date
# 2014-10-01    178.0000 38088400.0000 104240000.0000
# 2014-10-02    176.0000 25119400.0000  75490000.0000
# 2014-10-03    499.0000 32453200.0000  87940000.0000
# 2014-10-04         NaN           NaN            NaN
# 2014-10-05         NaN           NaN            NaN
# ...                ...           ...            ...
# 2021-05-26 170526.0000 17771600.0000 258780000.0000
# 2021-05-27  35794.0000 24426200.0000 520630000.0000
# 2021-05-28   2415.0000 18270200.0000 290850000.0000
# 2021-05-29         NaN           NaN            NaN
# 2021-05-30         NaN           NaN            NaN
#
# [2434 rows x 36 columns]

# %%
# Get all the close price df. 
close = df.Close.copy() # select daily close prices only
close

# The close price of all the stocks.
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 124.6700   383.6150    1.2628 1214.6000  45.9000 16804.7109
# 2014-10-02 124.1700   375.0720    1.2624 1214.2000  45.7600 16801.0508
# 2014-10-03 126.3600   359.5120    1.2671 1192.2000  46.0900 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 251.4900 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 249.3100 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 249.6800 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
close.describe()

# Describe the data: make some aggrigation.
# Out:
#              BA    BTC-USD  EURUSD=X      GC=F      MSFT       ^DJI
# count 1677.0000  2434.0000 1735.0000 1674.0000 1677.0000  1677.0000
# mean   228.7380  7613.8314    1.1406 1372.0145  106.3144 23004.3727
# std     94.3742 11611.1824    0.0501  235.7154   60.7722  4659.9220
# min     95.0100   178.1030    1.0390 1050.8000   40.2900 15660.1797
# 25%    143.3400   534.6280    1.1054 1216.5500   54.8300 18086.4004
# 50%    189.0800  4368.3750    1.1300 1283.1500   89.7100 23625.3398
# 75%    335.1600  9205.5750    1.1777 1482.3000  138.9000 26289.9805
# max    440.6200 63503.4570    1.2822 2051.5000  261.9700 34777.7617

# %%
close.BA.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
close.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# oops...its not normalized...

# %% [markdown]
# __Take Home: Absolute Prices are absolutely meaningless/useless (in most cases)__ <br>
# - Prices that are on a different scale are hard to compare
# - A higher Price does not imply a higher value or a better performance

# %% [markdown]
# ## Normalizing Financial Time Series to a Base Value (100)

# %% [markdown]
# __-> all instruments start at the very same Level (Base Value)__

# %%
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 124.6700   383.6150    1.2628 1214.6000  45.9000 16804.7109
# 2014-10-02 124.1700   375.0720    1.2624 1214.2000  45.7600 16801.0508
# 2014-10-03 126.3600   359.5120    1.2671 1192.2000  46.0900 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 251.4900 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 249.3100 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 249.6800 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
close.iloc[0,0] # first price BA
# Out:
# 124.66999816894533

# %%
# devide all closes prices of `BA` by yhe first price, with base off 100
close.BA.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2014-10-01   100.0000
# 2014-10-02    99.5989
# 2014-10-03   101.3556
# 2014-10-04        NaN
# 2014-10-05        NaN
#                ...
# 2021-05-26   193.6071
# 2021-05-27   201.0909
# 2021-05-28   198.1391
# 2021-05-29        NaN
# 2021-05-30        NaN
# Name: BA, Length: 2434, dtype: float64

# %%
close.iloc[0] # first Price all tickers
# Out:
# BA           124.6700
# BTC-USD      383.6150
# EURUSD=X       1.2628
# GC=F        1214.6000
# MSFT          45.9000
# ^DJI       16804.7109
# Name: 2014-10-01 00:00:00, dtype: float64

# %%
# normalize all the close price of each stock. 
# we devide each stock close price with the first close price of each stock.
# (this is the resson that the first row of close price is exactly 100). 
# we normalize with base of 100. 
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#                  BA    BTC-USD  EURUSD=X     GC=F     MSFT     ^DJI
# Date
# 2014-10-01 100.0000   100.0000  100.0000 100.0000 100.0000 100.0000
# 2014-10-02  99.5989    97.7730   99.9672  99.9671  99.6950  99.9782
# 2014-10-03 101.3556    93.7169  100.3345  98.1558 100.4139 101.2198
# 2014-10-04      NaN    85.7281       NaN      NaN      NaN      NaN
# 2014-10-05      NaN    83.5499       NaN      NaN      NaN      NaN
# ...             ...        ...       ...      ...      ...      ...
# 2021-05-26 193.6071 10243.1344   96.9969 156.5371 547.9085 204.2466
# 2021-05-27 201.0909 10019.6733   96.5495 156.0761 543.1590 205.0892
# 2021-05-28 198.1391  9305.5815   96.5542 156.6359 543.9651 205.4748
# 2021-05-29      NaN  9023.6480       NaN      NaN      NaN      NaN
# 2021-05-30      NaN  9300.5044       NaN      NaN      NaN      NaN
#
# [2434 rows x 6 columns]

# %%
# Now, we can plot that better. 
# logy => logaritmich scale on `y` axis.
norm.dropna().plot(figsize = (15, 8), fontsize = 13, logy = True)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# __Take Home: Normalized Prices help to compare Financial Instruments...<br>
# ...but they are limited when it comes to measuring/comparing Performance in more detail.__

# %%
close.to_csv("close.csv")

# %% [markdown]
# ---

# %% [markdown]
# ## Price Changes and Financial Returns

# %% [markdown]
# __More meaningful/useful than Prices: Price changes__

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8")

# %%
# Grab the close csv file
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 124.6700   383.6150    1.2628 1214.6000  45.9000 16804.7109
# 2014-10-02 124.1700   375.0720    1.2624 1214.2000  45.7600 16801.0508
# 2014-10-03 126.3600   359.5120    1.2671 1192.2000  46.0900 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 251.4900 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 249.3100 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 249.6800 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
# Get a copy the microsodt stock, drop NuNs, convert to data frame, 
msft = close.MSFT.dropna().to_frame().copy()

# %%
msft
# Out:
#                MSFT
# Date
# 2014-10-01  45.9000
# 2014-10-02  45.7600
# 2014-10-03  46.0900
# 2014-10-06  46.0900
# 2014-10-07  45.5300
# ...             ...
# 2021-05-24 250.7800
# 2021-05-25 251.7200
# 2021-05-26 251.4900
# 2021-05-27 249.3100
# 2021-05-28 249.6800
#
# [1677 rows x 1 columns]

# %%
# Rename the column name from MSFT to Price. 
msft.rename(columns = {"MSFT":"Price"}, inplace = True)

# %%
msft
# Out:
#               Price
# Date
# 2014-10-01  45.9000
# 2014-10-02  45.7600
# 2014-10-03  46.0900
# 2014-10-06  46.0900
# 2014-10-07  45.5300
# ...             ...
# 2021-05-24 250.7800
# 2021-05-25 251.7200
# 2021-05-26 251.4900
# 2021-05-27 249.3100
# 2021-05-28 249.6800
#
# [1677 rows x 1 columns]

# %%
# Shift the price one step ahead.
msft.shift(periods = 1)
# Out:
#               Price
# Date
# 2014-10-01      NaN
# 2014-10-02  45.9000
# 2014-10-03  45.7600
# 2014-10-06  46.0900
# 2014-10-07  46.0900
# ...             ...
# 2021-05-24 245.1700
# 2021-05-25 250.7800
# 2021-05-26 251.7200
# 2021-05-27 251.4900
# 2021-05-28 249.3100
#
# [1677 rows x 1 columns]

# %%
# Create price lag of one. 
msft["P_lag1"] = msft.shift(periods = 1)
msft
# Out:
#               Price   P_lag1
# Date
# 2014-10-01  45.9000      NaN
# 2014-10-02  45.7600  45.9000
# 2014-10-03  46.0900  45.7600
# 2014-10-06  46.0900  46.0900
# 2014-10-07  45.5300  46.0900
# ...             ...      ...
# 2021-05-24 250.7800 245.1700
# 2021-05-25 251.7200 250.7800
# 2021-05-26 251.4900 251.7200
# 2021-05-27 249.3100 251.4900
# 2021-05-28 249.6800 249.3100
#
# [1677 rows x 2 columns]

# %% [markdown]
# __Absolute Price Changes__ (Difference)

# %%
# Compute the different between the price, and the lag1. 
msft["P_diff"] = msft.Price.sub(msft.P_lag1) # Alternative 1

# %%
msft
# Out:
#               Price   P_lag1  P_diff
# Date
# 2014-10-01  45.9000      NaN     NaN
# 2014-10-02  45.7600  45.9000 -0.1400
# 2014-10-03  46.0900  45.7600  0.3300
# 2014-10-06  46.0900  46.0900  0.0000
# 2014-10-07  45.5300  46.0900 -0.5600
# ...             ...      ...     ...
# 2021-05-24 250.7800 245.1700  5.6100
# 2021-05-25 251.7200 250.7800  0.9400
# 2021-05-26 251.4900 251.7200 -0.2300
# 2021-05-27 249.3100 251.4900 -2.1800
# 2021-05-28 249.6800 249.3100  0.3700
#
# [1677 rows x 3 columns]

# %%
# Another way is to call the diff function.
# compute the diff between `Price` and its periods if 1.
# (Price_i - Price_i-1) 
msft["P_diff2"] = msft.Price.diff(periods = 1)  # Alternative 2

# %%
# See? 
msft
# Out:
#               Price   P_lag1  P_diff  P_diff2
# Date
# 2014-10-01  45.9000      NaN     NaN      NaN
# 2014-10-02  45.7600  45.9000 -0.1400  -0.1400
# 2014-10-03  46.0900  45.7600  0.3300   0.3300
# 2014-10-06  46.0900  46.0900  0.0000   0.0000
# 2014-10-07  45.5300  46.0900 -0.5600  -0.5600
# ...             ...      ...     ...      ...
# 2021-05-24 250.7800 245.1700  5.6100   5.6100
# 2021-05-25 251.7200 250.7800  0.9400   0.9400
# 2021-05-26 251.4900 251.7200 -0.2300  -0.2300
# 2021-05-27 249.3100 251.4900 -2.1800  -2.1800
# 2021-05-28 249.6800 249.3100  0.3700   0.3700
#
# [1677 rows x 4 columns]

# %%
# Its equal...of course.
msft.P_diff.equals(msft.P_diff2)
# Out:
# True

# %% [markdown]
# __-> Absolute Price Changes are not meaningful__

# %% [markdown]
# __Relative/Percentage Price Changes__ (Returns)

# %%
# Calculate the different between `Price` and `Price lag 1` in precents (%)
# this is the return on precents %... 
msft.Price.div(msft.P_lag1) - 1 # Alternative 1
# Out:
# Date
# 2014-10-01       NaN
# 2014-10-02   -0.0031
# 2014-10-03    0.0072
# 2014-10-06    0.0000
# 2014-10-07   -0.0122
#                ...
# 2021-05-24    0.0229
# 2021-05-25    0.0037
# 2021-05-26   -0.0009
# 2021-05-27   -0.0087
# 2021-05-28    0.0015
# Length: 1677, dtype: float64

# %%
msft["Returns"] = msft.Price.pct_change(periods = 1) # Alternative 2
msft
# Out:
#               Price   P_lag1  P_diff  P_diff2  Returns
# Date
# 2014-10-01  45.9000      NaN     NaN      NaN      NaN
# 2014-10-02  45.7600  45.9000 -0.1400  -0.1400  -0.0031
# 2014-10-03  46.0900  45.7600  0.3300   0.3300   0.0072
# 2014-10-06  46.0900  46.0900  0.0000   0.0000   0.0000
# 2014-10-07  45.5300  46.0900 -0.5600  -0.5600  -0.0122
# ...             ...      ...     ...      ...      ...
# 2021-05-24 250.7800 245.1700  5.6100   5.6100   0.0229
# 2021-05-25 251.7200 250.7800  0.9400   0.9400   0.0037
# 2021-05-26 251.4900 251.7200 -0.2300  -0.2300  -0.0009
# 2021-05-27 249.3100 251.4900 -2.1800  -2.1800  -0.0087
# 2021-05-28 249.6800 249.3100  0.3700   0.3700   0.0015
#
# [1677 rows x 5 columns]

# %%
# proof on concept...see? its calculate the % 
46.0900 / 45.7600 - 1
# Out:
# 0.007211538461538547

# %%
(46.0900 / 45.7600 - 1) * 100
# Out:
# 0.7211538461538547

# %% [markdown]
# __Take Home: Relative Price Changes (Returns) are meaningful and comparable across instruments__

# %%
msft.drop(columns = ["P_lag1", "P_diff", "P_diff2"], inplace = True)

# %%
msft
# Out:
#               Price  Returns
# Date
# 2014-10-01  45.9000      NaN
# 2014-10-02  45.7600  -0.0031
# 2014-10-03  46.0900   0.0072
# 2014-10-06  46.0900   0.0000
# 2014-10-07  45.5300  -0.0122
# ...             ...      ...
# 2021-05-24 250.7800   0.0229
# 2021-05-25 251.7200   0.0037
# 2021-05-26 251.4900  -0.0009
# 2021-05-27 249.3100  -0.0087
# 2021-05-28 249.6800   0.0015
#
# [1677 rows x 2 columns]

# %%
msft.to_csv("msft.csv")

# %% [markdown]
# ## Measuring Reward and Risk of an Investment

# %% [markdown]
# __General Rule in Finance/Investing: Higher Risk must be rewarded with higher Returns__.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8")

# %%
# Load the microsoft price and return 
# the return here -> return in precents.
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2014-10-01  45.9000      NaN
# 2014-10-02  45.7600  -0.0031
# 2014-10-03  46.0900   0.0072
# 2014-10-06  46.0900   0.0000
# 2014-10-07  45.5300  -0.0122
# ...             ...      ...
# 2021-05-24 250.7800   0.0229
# 2021-05-25 251.7200   0.0037
# 2021-05-26 251.4900  -0.0009
# 2021-05-27 249.3100  -0.0087
# 2021-05-28 249.6800   0.0015
#
# [1677 rows x 2 columns]

# %%
msft.Price.plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# - **Reward**: Positive Returns
# - **Risk**: Volatility of Returns

# %%
# Let's get a summery statistics.
# such as arithmetic mean, arithmetic std, and so on...  
msft.describe()
# Out:
#           Price   Returns
# count 1677.0000 1676.0000
# mean   106.3144    0.0012
# std     60.7722    0.0173
# min     40.2900   -0.1474
# 25%     54.8300   -0.0062
# 50%     89.7100    0.0009
# 75%    138.9000    0.0091
# max    261.9700    0.1422

# %%
mu = msft.Returns.mean() # arithmetic mean return -> Reward
mu

# In avarage, the return is positive...
# Out:
# 0.001159781798206695

# %%
sigma = msft.Returns.std() # standard deviation of returns -> Risk/Volatility
sigma
# Out:
# 0.017256078433477862

# %%
np.sqrt(msft.Returns.var())
# Out:
# 0.017256078433477862

# %% [markdown]
# ---

# %% [markdown]
# ## Investment Multiple and CAGR

# %% [markdown]
# __Two alternative reward metrics that are more intuitive and easier to interpret.__

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2014-10-01  45.9000      NaN
# 2014-10-02  45.7600  -0.0031
# 2014-10-03  46.0900   0.0072
# 2014-10-06  46.0900   0.0000
# 2014-10-07  45.5300  -0.0122
# ...             ...      ...
# 2021-05-24 250.7800   0.0229
# 2021-05-25 251.7200   0.0037
# 2021-05-26 251.4900  -0.0009
# 2021-05-27 249.3100  -0.0087
# 2021-05-28 249.6800   0.0015
#
# [1677 rows x 2 columns]

# %% [markdown]
# __Investment Multiple__: Ending Value of 1 [Dollar] invested. <br>
# Multiple = Ending Value / Initial Investment

# %%
# Investment Multiple in other words:
# you invested 1$ in date `x`, what the profit that you earned from this
# 1$ at date `y` ? 5.43$  
# so, you earned X5.4  
# Each 1$ of invesment, you made 5.43$

multiple = (msft.Price[-1] / msft.Price[0])
multiple
# Out:
# 5.43965107571966

# %% [markdown]
# __Price Increase (in %)__

# %%
# The proce increse in 443% !  
(multiple - 1) * 100
# Out:
# 443.96510757196603

# %%
# similar/identical concept: Normalized Price with Base Value 1
msft.Price / msft.Price[0]
# Out:
# Date
# 2014-10-01   1.0000
# 2014-10-02   0.9969
# 2014-10-03   1.0041
# 2014-10-06   1.0041
# 2014-10-07   0.9919
#               ...
# 2021-05-24   5.4636
# 2021-05-25   5.4841
# 2021-05-26   5.4791
# 2021-05-27   5.4316
# 2021-05-28   5.4397
# Name: Price, Length: 1677, dtype: float64

# %% [markdown]
# __Drawback of Investment Multiple: Doesn´t take into account investment Period. Meaningful only in conjunction with Investment Period.__

# %% [markdown]
# __Compound Annual Growth Rate (CAGR)__: The (constant annual) rate of return that would be required for an investment to grow from its beginning balance to its ending balance, assuming the profits were reinvested at the end of each year of the investment's lifespan. (Wikipedia)

# %%
# start time
start = msft.index[0]
start
# Out:
# Timestamp('2014-10-01 00:00:00')

# %%
# end time
end = msft.index[-1]
end
# Out:
# Timestamp('2021-05-28 00:00:00')

# %%
# number of days between start to end time
td = end - start
td
# Out:
# Timedelta('2431 days 00:00:00')

# %%
# time in years.
td_years = td.days / 365.25
td_years
# Out:
# 6.655715263518139

# %%
# compute the annual growth rate 
# 0.28978 -> annual growth of 28.9%
cagr = multiple**(1 / td_years) - 1 
cagr
# Out:
# 0.2897846506194157

# %%
# the same calculation, but from strech. 

cagr = (msft.Price[-1]/msft.Price[0])**(1/((msft.index[-1] - msft.index[0]).days / 365.25)) - 1 # long
cagr
# Out:
# 0.2897846506194157

# %%
(1 + cagr)**(td_years) # alternative #2 to calculate multiple (cagr)
# Out:
# 5.439651075719659

# %% [markdown]
# __-> CAGR can be used to compare Investments with different investment horizons.__

# %% [markdown]
# ---

# %% [markdown]
# ## Compound Returns & Geometric Mean Return

# %%
# the microsoft stock
msft
# Out:
#               Price  Returns
# Date
# 2014-10-01  45.9000      NaN
# 2014-10-02  45.7600  -0.0031
# 2014-10-03  46.0900   0.0072
# 2014-10-06  46.0900   0.0000
# 2014-10-07  45.5300  -0.0122
# ...             ...      ...
# 2021-05-24 250.7800   0.0229
# 2021-05-25 251.7200   0.0037
# 2021-05-26 251.4900  -0.0009
# 2021-05-27 249.3100  -0.0087
# 2021-05-28 249.6800   0.0015
#
# [1677 rows x 2 columns]

# %%
# Calculate the multiple (as we did before.)
multiple = (1 + msft.Returns).prod() # alternative #3 to calculate multiple (compounding daily returns)
multiple
# Out:
# 5.4396510757198575

# %%
# Sum the returns.
n = msft.Returns.count()
n
# Out:
# 1676

# %%
# the avarage return in a day. 
geo_mean = multiple**(1/n) - 1 # Geometric mean return (daily)
geo_mean
# Out:
# 0.0010110805580043625

# %%
# The inverse calculation. (get back the multiple return)
(1 + geo_mean)**n # alternative #4 to calculate multiple (geometric mean)
# Out:
# 5.439651075720363

# %% [markdown]
# __-> Compound returns, CAGR & geometric mean return are closely related concepts__.

# %%
mu = msft.Returns.mean() # arithmetic mean return
mu
# Out:
# 0.001159781798206695

# %% [markdown]
# __The arithmetic mean return is always greater than the geometric mean return... and less useful__.

# %%
(1 + mu)**n # calculate multiple? not possible with arithmetic mean!
# Out:
# 6.977341539401793

# %% [markdown]
# ----------------------------

# %% [markdown]
# ## Preview: Simple Returns vs. Logarithmic Returns (log returns)

# %% [markdown]
# Very often log returns are used instead of simple returns.<br>
# - favourable characteristics of log returns
# - drawbacks of simple returns

# %% [markdown]
# ## Discrete Compounding
#
# When the number of compounding event increse -> the return of investment may be higher.
#
# > For example, compounding events of months, will return higher investment than year event.
#
# > A discrete compounding event refers to a specific time period at which interest or investment returns are calculated and added to the principal amount. This event occurs at fixed intervals, and the compounding frequency can vary depending on the financial instrument or investment.
#
# **Here are some key points to understand discrete compounding in finance:**
#
# - **Compounding Frequency**: In discrete compounding, the compounding frequency specifies how often interest or returns are added to the principal. Common compounding frequencies include annually (once a year), semi-annually (twice a year), quarterly (four times a year), monthly (twelve times a year), and daily (365 times a year), among others.

# %% [markdown]
# __Annual Compounding__ -> Interests accrue once a year at the end of the year

# %% [markdown]
# Your Savings Bank offers an interest rate of __8% p.a. (stated rate)__ with __annual compounding__ on your savings (__USD 100__).<br>
# Calculate the __value__ of your savings account __after one year__ and the corresponding __effective annual interest rate__.

# %% [markdown]
# __-> Interests are calculated and added to your savings account once at the end of each year.__

# %%
PV = 100
r = 0.08
n = 1

# %%
# value of one year.

100 * 1.08
# Out:
# 108.0

# %%
# FV -> future value
# PV -> current value
# (1 + r) -> the rate in precent 
# **n -> time period. 
FV = PV * (1 + r)**n
FV
# Out:
# 108.0

# %%
# How many precent the investment increse per n period? 
effective_annual_rate = (FV / PV)**(1/n) - 1 
effective_annual_rate
# Out:
# 0.08000000000000007

# %% [markdown]
# __Quarterly Compounding__ -> Interests accrue once a quarter at the end of the quarter

# %% [markdown]
# Your Savings Bank offers an interest rate of __8% p.a. (stated rate)__ with __quarterly compounding__ on your savings (__USD 100__).<br>
# Calculate the __value__ of your savings account __after one year__ and the corresponding __effective annual interest rate__.

# %% [markdown]
# __-> Interests are calculated and added to your savings account at the end of each quarter.__

# %%
PV = 100 # current money in the account.
r = 0.08 # rate
n = 1 # perion (1 year)
m = 4 # 4 qurter in year.

# %%
100 * 1.02 * 1.02 * 1.02 * 1.02
# Out:
# 108.243216

# %%
FV = PV * (1 + r/m)**(n*m)
FV
# Out:
# 108.243216

# %%
effective_annual_rate = (FV / PV)**(1/n) - 1 
effective_annual_rate
# Out:
# 0.08243215999999998

# %% [markdown]
# __-> Quarterly compounding is favourable (everything else equal) as we earn compound interest (interest on interest).__

# %% [markdown]
# __Monthly Compounding__ -> Interests accrue once a month at the end of the month

# %% [markdown]
# Your Savings Bank offers an interest rate of __8% p.a. (stated rate)__ with __monthly compounding__ on your savings (__USD 100__).<br>
# Calculate the __value__ of your savings account __after one year__ and the corresponding __effective annual interest rate__.

# %% [markdown]
# __-> Interests are calculated and added to your savings account at the end of each month.__

# %%
PV = 100
r = 0.08
n = 1
m = 12

# %%
FV = PV * (1 + r/m)**(n*m)
FV
# Out:
# 108.29995068075098

# %%
effective_annual_rate = ((FV / PV)**(1/n) - 1) 
effective_annual_rate
# Out:
# 0.08299950680750978

# %% [markdown]
# ## Continuous Compounding

# %%
import numpy as np

# %% [markdown]
# Your Savings Bank offers an interest rate of __8% p.a. (stated rate)__ with __continuous compounding__ on your savings (__USD 100__).<br>
# Calculate the __value__ of your savings account __after one year__ and the corresponding __effective annual interest rate__.

# %% [markdown]
# __-> Interests are calculated and added to your savings account continuously (infinitely large number of compounding events).__ -> continuous exponential growth that can be observed in nature

# %%
PV = 100
r = 0.08
n = 1
m = 100000 # approx.infinity

# %%
FV = PV * (1 + r/m)**(n*m) # approx. with large m
FV
# Out:
# 108.32870330122834

# %%
FV = PV * np.exp(n * r) # exact math with e (euler number)
FV
# Out:
# 108.32870676749586

# %%
euler = np.exp(1)
euler
# Out:
# 2.718281828459045

# %%
PV * euler**(n * r)
# Out:
# 108.29995068075098

# %%
effective_annual_rate = ((FV / PV)**(1/n) - 1) # Alt 1
effective_annual_rate
# Out:
# 0.08328706767495864

# %%
effective_annual_rate = np.exp(r) - 1 # Alt 2
effective_annual_rate
# Out:
# 0.08299950680750978

# %% [markdown]
# Let´s assume we only observe PV and FV, how to calculate the stated rate/continuously compounded rate of 8%?

# %%
r = np.log(FV / PV) # inverse calculation -> use log (Alt 1)
r
# Out:
# 0.08000000000000007

# %%
r = np.log(effective_annual_rate + 1) # inverse calculation -> use log (Alt 2)
r
# Out:
# 0.07973451262402206

# %% [markdown]
# __Take Home: Prices of traded Financial Instruments change (approx.) continuously. <br>
# -> Intuitively, it makes a lot of sense to work with log returns.__

# %% [markdown]
# ---

# %% [markdown]
# ## Log Returns

# %% [markdown]
# **Advantages of Log Returns:**
#
# 1. **Additivity**: Log returns are additive, which means that you can sum them over different time periods to calculate the cumulative return. This property is especially useful when analyzing returns over multiple periods. In contrast, simple returns are not additive, and calculating the cumulative return using simple returns can lead to inaccuracies.
#
# 2. **Normal Distribution:** Log returns tend to follow a normal distribution, which makes them suitable for many statistical and financial models that assume normally distributed returns. This simplifies modeling and analysis.
#
# 3. **Stationarity:** Log returns often exhibit better stationarity, which means that their statistical properties remain more consistent over time. This makes them more amenable to various time series analysis techniques.
#
# 4. **Percentage vs. Dollar** Changes: Log returns express returns as a percentage change in the value of an asset, which is often more informative and easier to interpret than dollar changes, especially when comparing assets with different price levels.
#
# 5. **Continuous Compounding:** Log returns are closely related to the concept of continuous compounding, which is a fundamental idea in finance. When returns are compounded continuously, the log returns closely approximate the actual compounded returns.
#
# 6. **Use in Risk and Portfolio Management:** Log returns are widely used in risk and portfolio management, including the calculation of risk measures like volatility and in the formulation of portfolio optimization models, such as the Markowitz portfolio theory.
#
# 7. **Mathematical Properties:** Logarithmic returns have desirable mathematical properties that simplify various financial calculations and modeling, such as pricing options using the Black-Scholes model.

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.6f}'.format

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#                 Price   Returns
# Date
# 2014-10-01  45.900002       NaN
# 2014-10-02  45.759998 -0.003050
# 2014-10-03  46.090000  0.007212
# 2014-10-06  46.090000  0.000000
# 2014-10-07  45.529999 -0.012150
# ...               ...       ...
# 2021-05-24 250.779999  0.022882
# 2021-05-25 251.720001  0.003748
# 2021-05-26 251.490005 -0.000914
# 2021-05-27 249.309998 -0.008668
# 2021-05-28 249.679993  0.001484
#
# [1677 rows x 2 columns]

# %%
# Compute the log return
msft["log_ret"] = np.log(msft.Price / msft.Price.shift()) # daily log returns

# %%
msft
# Out:
#                 Price   Returns   log_ret
# Date
# 2014-10-01  45.900002       NaN       NaN
# 2014-10-02  45.759998 -0.003050 -0.003055
# 2014-10-03  46.090000  0.007212  0.007186
# 2014-10-06  46.090000  0.000000  0.000000
# 2014-10-07  45.529999 -0.012150 -0.012225
# ...               ...       ...       ...
# 2021-05-24 250.779999  0.022882  0.022624
# 2021-05-25 251.720001  0.003748  0.003741
# 2021-05-26 251.490005 -0.000914 -0.000914
# 2021-05-27 249.309998 -0.008668 -0.008706
# 2021-05-28 249.679993  0.001484  0.001483
#
# [1677 rows x 3 columns]

# %%
msft.describe()
# Out:
#             Price     Returns     log_ret
# count 1677.000000 1676.000000 1676.000000
# mean   106.314377    0.001160    0.001011
# std     60.772246    0.017256    0.017249
# min     40.290001   -0.147390   -0.159453
# 25%     54.830002   -0.006177   -0.006196
# 50%     89.709999    0.000918    0.000918
# 75%    138.899994    0.009110    0.009069
# max    261.970001    0.142169    0.132929

# %%
mu = msft.log_ret.mean() # mean log return -> Reward
mu
# Out:
# 0.0010105697603329652

# %%
sigma = msft.log_ret.std() # standard deviation of log returns -> Risk/Volatility
sigma
# Out:
# 0.01724882682847896

# %% [markdown]
# ## Simple Returns vs Log Returns ( Part 1)

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.6f}'.format

# %%
# Create a simple data frame 
df = pd.DataFrame(data = [100, 50, 90], columns = ["Price"])
df
# Out:
#    Price
# 0    100
# 1     50
# 2     90

# %%
df["SR"] = df.Price.pct_change() # simple returns

# %%
df["LR"] = np.log(df.Price / df.Price.shift()) # log returns

# %%
df
# Out:
#    Price        SR        LR
# 0    100       NaN       NaN
# 1     50 -0.500000 -0.693147
# 2     90  0.800000  0.587787

# %%
periods = df.SR.count()
periods
# Out:
# 2

# %% [markdown]
# __The arithmetic mean of simple returns can be misleading!__
#
# Its not impossible that we start with invertment of 100$, and we done with 90%, and the mean reatun is positive!! its not make sance! its not correct!

# %%
mean_sr = df.SR.mean()
mean_sr

# The mean DO NOT take in account some thinks.
# Out:
# 0.15000000000000002

# %%
100 * (1 + mean_sr)**periods # wrong!!!
# Out:
# 132.24999999999997

# %% [markdown]
# __We should use Compound Simple Returns / Geometric Mean, or even better...__

# %%
geo_mean = (1 + df.SR).prod()**(1 / periods) - 1
geo_mean
# Out:
# -0.05131670194948623

# %%
100 * (1 + geo_mean)**periods # correct!!!
# Out:
# 89.99999999999999

# %% [markdown]
# __...Log Returns which are additive over time!__

# %%
sum_lr = df.LR.sum()
sum_lr
# Out:
# -0.10536051565782623

# %%
100 * np.exp(sum_lr) # correct!!!
# Out:
# 90.0

# %%
mean_lr = df.LR.mean()
mean_lr
# Out:
# -0.05268025782891311

# %%
100 * np.exp(mean_lr * periods) # correct!!!
# Out:
# 90.0

# %% [markdown]
# **Take Home: Log Returns are additive over time. Simple Returns are not additive over time (but they can be multiplied/compounded)**

# %% [markdown]
# ## Simple Returns vs. Log Returns (Part 2)

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.6f}'.format

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])

# %%
msft["log_ret"] = np.log(msft.Price / msft.Price.shift())

# %%
msft
# Out:
#                 Price   Returns   log_ret
# Date
# 2014-10-01  45.900002       NaN       NaN
# 2014-10-02  45.759998 -0.003050 -0.003055
# 2014-10-03  46.090000  0.007212  0.007186
# 2014-10-06  46.090000  0.000000  0.000000
# 2014-10-07  45.529999 -0.012150 -0.012225
# ...               ...       ...       ...
# 2021-05-24 250.779999  0.022882  0.022624
# 2021-05-25 251.720001  0.003748  0.003741
# 2021-05-26 251.490005 -0.000914 -0.000914
# 2021-05-27 249.309998 -0.008668 -0.008706
# 2021-05-28 249.679993  0.001484  0.001483
#
# [1677 rows x 3 columns]

# %% [markdown]
# __Investment Multiple__

# %%
msft.Returns.add(1).prod() # compounding simple returns ("compound returns")
# Out:
# 5.4396510757198575

# %%
np.exp(msft.log_ret.sum())  # adding log returns ("cumulative returns")
# Out:
# 5.439651075719645

# %% [markdown]
# __Normalized Prices with Base 1__

# %%
msft.Returns.add(1).cumprod() # compounding simple returns ("compound returns")
# Out:
# Date
# 2014-10-01        NaN
# 2014-10-02   0.996950
# 2014-10-03   1.004139
# 2014-10-06   1.004139
# 2014-10-07   0.991939
#                ...
# 2021-05-24   5.463616
# 2021-05-25   5.484096
# 2021-05-26   5.479085
# 2021-05-27   5.431590
# 2021-05-28   5.439651
# Name: Returns, Length: 1677, dtype: float64

# %%
np.exp(msft.log_ret.cumsum()) # adding log returns ("cumulative returns")
# Out:
# Date
# 2014-10-01        NaN
# 2014-10-02   0.996950
# 2014-10-03   1.004139
# 2014-10-06   1.004139
# 2014-10-07   0.991939
#                ...
# 2021-05-24   5.463616
# 2021-05-25   5.484096
# 2021-05-26   5.479085
# 2021-05-27   5.431590
# 2021-05-28   5.439651
# Name: log_ret, Length: 1677, dtype: float64

# %%
msft.log_ret.cumsum().apply(np.exp) # adding log returns ("cumulative returns")
# Out:
# Date
# 2014-10-01        NaN
# 2014-10-02   0.996950
# 2014-10-03   1.004139
# 2014-10-06   1.004139
# 2014-10-07   0.991939
#                ...
# 2021-05-24   5.463616
# 2021-05-25   5.484096
# 2021-05-26   5.479085
# 2021-05-27   5.431590
# 2021-05-28   5.439651
# Name: log_ret, Length: 1677, dtype: float64

# %% [markdown]
# __CAGR__ (annual growth)

# %%
(msft.Price[-1]/msft.Price[0])**(1/((msft.index[-1] - msft.index[0]).days / 365.25)) - 1
# Out:
# 0.2897846506194157

# %%
trading_days_year = msft.Returns.count() / ((msft.index[-1] - msft.index[0]).days / 365.25)
trading_days_year
# Out:
# 251.81365693130397

# %%
np.exp(msft.log_ret.mean() * trading_days_year) - 1 # correct with mean of daily log returns!
# Out:
# 0.2897846506194153

# %%
msft.Returns.mean() * trading_days_year # incorrect with mean of daily simple returns!
# Out:
# 0.2920488958487915

# %%
# 252 -> the market activity days.. 
np.exp(msft.log_ret.mean() * 252) - 1 # good approximation (for us stocks)
# Out:
# 0.29002755628143806

# %% [markdown]
# ---

# %% [markdown]
# ## Performance Comparison

# %% [markdown]
# __General Rule in Finance/Investing: Higher Risk must be rewarded with higher Returns__.

# %% [markdown]
# __Which instrument(s) performed best/worst in the past in terms of risk & return?__

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 124.6700   383.6150    1.2628 1214.6000  45.9000 16804.7109
# 2014-10-02 124.1700   375.0720    1.2624 1214.2000  45.7600 16801.0508
# 2014-10-03 126.3600   359.5120    1.2671 1192.2000  46.0900 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 251.4900 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 249.3100 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 249.6800 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BA        1677 non-null   float64
#  1   BTC-USD   2434 non-null   float64
#  2   EURUSD=X  1735 non-null   float64
#  3   GC=F      1674 non-null   float64
#  4   MSFT      1677 non-null   float64
#  5   ^DJI      1677 non-null   float64
# dtypes: float64(6)
# memory usage: 133.1 KB

# %%
close.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
# compute the log return.
np.log(close / close.shift()).info() # keep NaN
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BA        1312 non-null   float64
#  1   BTC-USD   2433 non-null   float64
#  2   EURUSD=X  1384 non-null   float64
#  3   GC=F      1309 non-null   float64
#  4   MSFT      1312 non-null   float64
#  5   ^DJI      1312 non-null   float64
# dtypes: float64(6)
# memory usage: 133.1 KB

# %%
# Calculate log return, and drop all NaN
close.apply(lambda x: np.log(x.dropna() / x.dropna().shift())).info() # remove NaN
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Freq: D
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BA        1676 non-null   float64
#  1   BTC-USD   2433 non-null   float64
#  2   EURUSD=X  1734 non-null   float64
#  3   GC=F      1673 non-null   float64
#  4   MSFT      1676 non-null   float64
#  5   ^DJI      1676 non-null   float64
# dtypes: float64(6)
# memory usage: 133.1 KB

# %%
# Compute the log return, and store that in the DataFrame. 
returns = close.apply(lambda x: np.log(x.dropna() / x.dropna().shift()))
returns
# Out:
#                 BA  BTC-USD  EURUSD=X    GC=F    MSFT    ^DJI
# Date
# 2014-10-01     NaN      NaN       NaN     NaN     NaN     NaN
# 2014-10-02 -0.0040  -0.0225   -0.0003 -0.0003 -0.0031 -0.0002
# 2014-10-03  0.0175  -0.0424    0.0037 -0.0183  0.0072  0.0123
# 2014-10-04     NaN  -0.0891       NaN     NaN     NaN     NaN
# 2014-10-05     NaN  -0.0257       NaN     NaN     NaN     NaN
# ...            ...      ...       ...     ...     ...     ...
# 2021-05-26  0.0026   0.0230    0.0028  0.0017 -0.0009  0.0003
# 2021-05-27  0.0379  -0.0221   -0.0046 -0.0029 -0.0087  0.0041
# 2021-05-28 -0.0148  -0.0739    0.0000  0.0036  0.0015  0.0019
# 2021-05-29     NaN  -0.0308       NaN     NaN     NaN     NaN
# 2021-05-30     NaN   0.0302       NaN     NaN     NaN     NaN
#
# [2434 rows x 6 columns]

# %%
returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Freq: D
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BA        1676 non-null   float64
#  1   BTC-USD   2433 non-null   float64
#  2   EURUSD=X  1734 non-null   float64
#  3   GC=F      1673 non-null   float64
#  4   MSFT      1676 non-null   float64
#  5   ^DJI      1676 non-null   float64
# dtypes: float64(6)
# memory usage: 133.1 KB

# %%
returns.describe()
# Out:
#              BA   BTC-USD  EURUSD=X      GC=F      MSFT      ^DJI
# count 1676.0000 2433.0000 1734.0000 1673.0000 1676.0000 1676.0000
# mean     0.0004    0.0019   -0.0000    0.0003    0.0010    0.0004
# std      0.0263    0.0395    0.0051    0.0094    0.0172    0.0120
# min     -0.2724   -0.4647   -0.0281   -0.0511   -0.1595   -0.1384
# 25%     -0.0092   -0.0123   -0.0031   -0.0042   -0.0062   -0.0034
# 50%      0.0007    0.0020   -0.0000    0.0003    0.0009    0.0007
# 75%      0.0105    0.0178    0.0029    0.0051    0.0091    0.0054
# max      0.2177    0.2251    0.0281    0.0578    0.1329    0.1076

# %%
summary = returns.agg(["mean", "std"]).T
summary
# Out:
#             mean    std
# BA        0.0004 0.0263
# BTC-USD   0.0019 0.0395
# EURUSD=X -0.0000 0.0051
# GC=F      0.0003 0.0094
# MSFT      0.0010 0.0172
# ^DJI      0.0004 0.0120

# %%
summary.columns = ["Mean", "Std"]
summary
# Out:
#             Mean    Std
# BA        0.0004 0.0263
# BTC-USD   0.0019 0.0395
# EURUSD=X -0.0000 0.0051
# GC=F      0.0003 0.0094
# MSFT      0.0010 0.0172
# ^DJI      0.0004 0.0120

# %% [markdown]
# __Mean Variance Analysis__
#
# - We can measure the risk anf reward of a stock by the `variance` and the `mean`.
#     - The more risk (high std), the more return.
#
# This analysis helps us to find the optimal asset to inverst/trade.

# %%
summary.plot(kind = "scatter", x = "Std", y = "Mean", figsize = (15,12), s = 50, fontsize = 15)

for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "Std"]+0.00005, summary.loc[i, "Mean"]+0.00005), size = 15)

plt.xlabel("Risk (std)", fontsize = 15)
plt.ylabel("Mean Return", fontsize = 15)
plt.title("Mean-Variance Analysis", fontsize = 20)
plt.show()

# %% [markdown]
# As you can see above, for example. `^DJI` and `BA` as the same return, but `BA` have more risk! so, we'll prefer to go on `^DJI` - because its the same return and less risk then `BA`.

# %% [markdown]
# -> There is __no clear "best-performer"__ among ["EURUSD=X", "GC=F", "^DJI", "MSFT", "BTC-USD"] (without further analysis). __Higher risk__ is getting rewarded with __higher returns__. __BA underperformed__.

# %% [markdown]
# __Take Home: Mean-Variance Analysis has one major shortcoming: It assumes that financial returns follow a Normal Distribution. That´s (typically) not True.<br> -> Standard Deviation of Returns underestimates the true/full risk of an Investment as it fails to measure "Tail Risks".__

# %% [markdown]
# ## Normality of Financial Returns
#
# > Checking the distribution of a stock return, is one of the most importent thinks, becase there are lot's of statistical measure, indicators and teqnuces that assume that the data is Gasussian.

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2014-10-01  45.9000      NaN
# 2014-10-02  45.7600  -0.0031
# 2014-10-03  46.0900   0.0072
# 2014-10-06  46.0900   0.0000
# 2014-10-07  45.5300  -0.0122
# ...             ...      ...
# 2021-05-24 250.7800   0.0229
# 2021-05-25 251.7200   0.0037
# 2021-05-26 251.4900  -0.0009
# 2021-05-27 249.3100  -0.0087
# 2021-05-28 249.6800   0.0015
#
# [1677 rows x 2 columns]

# %%
# Compute the log return
msft["log_ret"] = np.log(msft.Price / msft.Price.shift()) 
msft
# Out:
#               Price  Returns  log_ret
# Date
# 2014-10-01  45.9000      NaN      NaN
# 2014-10-02  45.7600  -0.0031  -0.0031
# 2014-10-03  46.0900   0.0072   0.0072
# 2014-10-06  46.0900   0.0000   0.0000
# 2014-10-07  45.5300  -0.0122  -0.0122
# ...             ...      ...      ...
# 2021-05-24 250.7800   0.0229   0.0226
# 2021-05-25 251.7200   0.0037   0.0037
# 2021-05-26 251.4900  -0.0009  -0.0009
# 2021-05-27 249.3100  -0.0087  -0.0087
# 2021-05-28 249.6800   0.0015   0.0015
#
# [1677 rows x 3 columns]

# %%
msft.describe()
# Out:
#           Price   Returns   log_ret
# count 1677.0000 1676.0000 1676.0000
# mean   106.3144    0.0012    0.0010
# std     60.7722    0.0173    0.0172
# min     40.2900   -0.1474   -0.1595
# 25%     54.8300   -0.0062   -0.0062
# 50%     89.7100    0.0009    0.0009
# 75%    138.9000    0.0091    0.0091
# max    261.9700    0.1422    0.1329

# %%
# Plot the histogram of log return, for see visually the distribution.
msft.log_ret.plot(kind = "hist", figsize = (15 ,8), bins = 100, fontsize = 15, density = False) # Frequency Distribution of log returns
plt.xlabel("Daily Returns", fontsize = 15)
plt.ylabel("Frequency", fontsize = 15)
plt.title("Frequency Distribution of Returns", fontsize = 20)
plt.show()

# %% [markdown]
# __Do MSFT Returns follow a Normal Distribution?__ <br><br>
# A normally distributed random variable can be fully described by its
# - __mean__
# - __standard deviation__

# %% [markdown]
# Higher Central Moments are zero:
# - __Skew = 0__ (measures symmetrie around the mean)
# - __(Excess) Kurtosis = 0__ (positve excess Kurtosis -> more observations in the "tails")

# %%
# Compute the mean of the log return
mu = msft.log_ret.mean()
mu
# Out:
# 0.0010105697603329652

# %%
# Compute the std of the log return
sigma = msft.log_ret.std()
sigma
# Out:
# 0.01724882682847896

# %% [markdown]
# __Now, Lets make a few statistical measure for check if the log return is Gaussian.__

# %%
import scipy.stats as stats

# %% [markdown]
# **Compute the skewness:**
# - We can see that the `skew != 0`. its mean that the distribution is not symmatric around the mean, and therefor its probably not normal distribution.
#     - `skew = -0.200705`, mean that there is negative assymetry. (the distribution assymetry to the negative.)

# %%
# Compute the skewness. 
stats.skew(msft.log_ret.dropna()) # in a Normal Distribution: skew == 0
# Out:
# -0.20070528675208313

# %% [markdown]
# **Compute the kurtosis**
# - We can see that the `kurtosis` is not 0, so its mean taht the distribution is not normal, becase there is a kurtosis.

# %%
stats.kurtosis(msft.log_ret.dropna(), fisher = True) # in a Normal Distribution: (fisher) kurtosis == 0
# Out:
# 10.733092631202133

# %% [markdown]
# __MSFT Returns exhibit "Fat Tails" (extreme positive/negative outcomes).__
#
# So, what we gonna to do?
# - base on the `mean` and `std`, `min` & `max` value of the distribution, we are going to create the expected normal distribution, and then we are going to compare the expected distribution to the actuall distribution.
#
# There is two cases:
# - If the expected and the actual distribution are similar, we can fill comftble that the  stocl distribution is normal.
# - else, the distribution of the stock return is not normal.

# %%
# 1. Create linear space with range of [min,max] log return.
x = np.linspace(msft.log_ret.min(), msft.log_ret.max(), 10000)
x
# Out:
# array([-0.15945341, -0.15942417, -0.15939493, ...,  0.1328705 ,
#         0.13289974,  0.13292898])

# %%
# 2. Using the probably density function, I create the 
# expected normal distribution with the next parameters:
# x -> the linear space
# loc -> location, the expected value (the mean)
# scale -> the std.
y = stats.norm.pdf(x, loc = mu, scale = sigma) # creating y values a for normal distribution with mu, sigma
y
# now, i created the expected normal distribution.
# Out:
# array([3.72735695e-18, 3.78660080e-18, 3.84677524e-18, ...,
#        4.72250419e-12, 4.66169105e-12, 4.60164778e-12])

# %%
# 3. Plot the expected normal distribution and the actual distribution
# for comparison.
plt.figure(figsize = (20, 8))
plt.hist(msft.log_ret, bins = 500, density = True, label = "Frequency Distribution of daily Returns (MSFT)")
plt.plot(x, y, linewidth = 3, color = "red", label = "Normal Distribution")
plt.title("Normal Distribution", fontsize = 20)
plt.xlabel("Daily Returns", fontsize = 15)
plt.ylabel("pdf", fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# We can see clearly that our distribution, is not normal.

# %% [markdown]
# __-> MSFT Returns exhibit "Fat Tails" (extreme positive/negative outcomes).__

# %% [markdown]
# **Hypotesis test - for testing whether our distribution is normally or not.**

# %% [markdown]
# - Testing the normality of MSFT Returns based on the sample (Oct 2014 to May 2021): <br>
# - Hypothesis Test with H0 Hypothesis: MSFT Returns (full population) follow a normal Distribution.

# %% [markdown]
# - `H0`: the null hypotheses; the data **is** normally distributed.
# - `H1`: the althernative hypotheses; the data **is not** normaly distributed

# %% [markdown]
# - `z_stat`: This variable holds the Z-statistic, which is a measure of how many standard deviations the sample data is from the mean of a normal distribution. In a normality test, a Z-statistic that is significantly different from zero may indicate that the data **significantly deviates from a normal distribution.**
#
# - `p_value`:  The p-value is a measure of the evidence against a null hypothesis. In the context of a normality test, **a small p-value** (typically less than 0.05) suggests that there is evidence to reject the null hypothesis that the data follows a normal distribution.

# %%
# Make the normal test (test if its normal)
# extract the z_stat, p_value:
# z_stat 
z_stat, p_value = stats.normaltest(msft.log_ret.dropna())

# %% [markdown]
# In that case, we can see that the **z-statistics** is big, and the **p-value** is small.
#
# **Its mean that we reject the H0. In other words, the data DONT came from normal distribution**

# %%
z_stat # high values -> reject H0
# Out:
# 326.8451656349759

# %%
p_value # low values (close to zero) -> reject H0
# Out:
# 1.0628551078061005e-71

# %%
round(p_value, 10)
# Out:
# 0.0

# %% [markdown]
# **Conclution**
# - . We checked if the distribution of stock return come from Gaussian.
# - We got that the **distribution of stock return DO NOT came from the normal distribution.**
#
# **What meaning of that?**
# - because its NOT came from noraml, we can trust on the `std` and `mean` (they are understatmant).
# - Do not expect that the stock behavior will be as normal distribution. we need to expect to exptreme events and uncerteny.
# - assume that the stock behavior as "random walk" (stock behavior randomaly)

# %% [markdown]
# __-> Assuming that MSFT Returns (generally) follow a Normal Distribution, there is 0% probability that we get that extreme outcomes in a sample.__

# %% [markdown]
# __Take Home: MSFT Returns don´t follow a Normal Distribution as they exhibit "Fat Tails". Extreme Events/Outcomes are not reflected in the Mean-Variance Analysis. The Standard Deviation of Returns underestimates true Risk.__

# %% [markdown]
# ## Annualizing Mean Return and Std of Returns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.6f}'.format
plt.style.use("seaborn-v0_8")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"], usecols = ["Date", "Price"])

# %%
msft
# Out:
#                 Price
# Date
# 2014-10-01  45.900002
# 2014-10-02  45.759998
# 2014-10-03  46.090000
# 2014-10-06  46.090000
# 2014-10-07  45.529999
# ...               ...
# 2021-05-24 250.779999
# 2021-05-25 251.720001
# 2021-05-26 251.490005
# 2021-05-27 249.309998
# 2021-05-28 249.679993
#
# [1677 rows x 1 columns]

# %%
# Compute the log return
msft["log_ret"] = np.log(msft.Price / msft.Price.shift())

# %%
# get the mean and std of log return, based on dayly returns.
msft.log_ret.agg(["mean", "std"])
# Out:
# mean   0.001011
# std    0.017249
# Name: log_ret, dtype: float64

# %%
# annualized mean return (mean reaturn in a year.)
ann_mu = msft.log_ret.mean() * 252 
ann_mu
# Out:
# 0.25466357960390723

# %%
# cagr -> compunted annual growth return
cagr = np.exp(ann_mu) - 1 # don´t mix up with cagr
cagr
# Out:
# 0.29002755628143806

# %%
# annualizing the risk (std of return.)
ann_std = msft.log_ret.std() * np.sqrt(252) 
ann_std
# Out:
# 0.27381663717464577

# %%
ann_std = np.sqrt(msft.log_ret.var() * 252) # annualized std of returns (Alt 2)
ann_std
# Out:
# 0.27381663717464577

# %% [markdown]
# ---

# %% [markdown]
# ## Resampling / Smoothing

# %%
# Plot the microsoft dat return
msft.Price.plot(figsize = (12, 8), title="Daily Return")
plt.legend()
plt.show()

# %%
# resample to monthly (month end)
# resample("M") -> resample to monthly frequency
# last() -> take the very last data point of each month 

monthly = msft.Price.resample("M").last() 

print(len(monthly))
monthly
# Out:
# 80
# Date
# 2014-10-31    46.950001
# 2014-11-30    47.810001
# 2014-12-31    46.450001
# 2015-01-31    40.400002
# 2015-02-28    43.849998
#                 ...
# 2021-01-31   231.960007
# 2021-02-28   232.380005
# 2021-03-31   235.770004
# 2021-04-30   252.179993
# 2021-05-31   249.679993
# Freq: M, Name: Price, Length: 80, dtype: float64

# %%
monthly.plot(figsize = (12, 8), title="Monthly Return")
plt.legend()
plt.show()

# %% [markdown]
# __How will the Mean-Variance Analysis change with smoothed data?__

# %%
freqs = ["A", "Q", "M", "W-Fri", "D"] # [annual,quarter,monthly,weekly,daily]
periods = [1, 4, 12, 52, 252] # [1year,4 qarters in a year, and so on..]

ann_mean = []
ann_std = []

# %%
# Compute the mean and std for each period, then store it in a list.
for i in range(5):
    # resample the freqiency 
    resamp = msft.Price.resample(freqs[i]).last()
    
    # compute the mean/std 
    period_mean_return = np.log(resamp / resamp.shift()).mean() * periods[i] 
    period_std_return = np.log(resamp / resamp.shift()).std() * np.sqrt(periods[i]) 
    
    # store the result
    ann_mean.append(period_mean_return) 
    ann_std.append(period_std_return)

# %%
# mean return for each period (frequency)
ann_mean
# Out:
# [0.24025765527761314,
#  0.258739013375891,
#  0.253837495704879,
#  0.253194152871532,
#  0.25289038013157555]

# %%
#  store the std and mean in a df.
summary = pd.DataFrame(data = {"ann_std":ann_std, "ann_mean":ann_mean}, index = freqs)
summary
# Out:
#        ann_std  ann_mean
# A     0.127250  0.240258
# Q     0.179314  0.258739
# M     0.204970  0.253837
# W-Fri 0.230859  0.253194
# D     0.267372  0.252890

# %%
# Plot the std and mean for each period.
summary.plot(kind = "scatter", x = "ann_std", y = "ann_mean", figsize = (15,12), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i, "ann_std"]+0.001, summary.loc[i, "ann_mean"]+0.001), size = 15)
plt.ylim(0, 0.3)
plt.xlabel("ann. Risk(std)", fontsize = 15)
plt.ylabel("ann. Return", fontsize = 15)
plt.title("Risk/Return", fontsize = 20)
plt.show()

# %% [markdown]
# __-> Smoothing reduces (observed) Risk__.

# %% [markdown]
# Dubious practices:
# - Managing (Manipulating) Performance in Performance Reportings.
# - Comparing assets with different granularity and pricing mechanisms -> e.g. non-listed (alternative assets) vs. listed assets
# - Adjusting granularity to investor´s (average) holding period -> Volatility is still there.

# %% [markdown]
# Take home massege - when you compare instroments, compare them on the same frequency.

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics

# %% [markdown]
# __(Another) general Rule in Finance/Investing: Past performance is not an indicator of future performance__.

# %%
msft
# Out:
#                 Price   log_ret
# Date
# 2014-10-01  45.900002       NaN
# 2014-10-02  45.759998 -0.003055
# 2014-10-03  46.090000  0.007186
# 2014-10-06  46.090000  0.000000
# 2014-10-07  45.529999 -0.012225
# ...               ...       ...
# 2021-05-24 250.779999  0.022624
# 2021-05-25 251.720001  0.003741
# 2021-05-26 251.490005 -0.000914
# 2021-05-27 249.309998 -0.008706
# 2021-05-28 249.679993  0.001483
#
# [1677 rows x 2 columns]

# %%
ann_mu = msft.log_ret.mean() * 252 # annualized mean return
ann_mu
# Out:
# 0.25466357960390723

# %%
ann_std = msft.log_ret.std() * np.sqrt(252) # annualized std of returns (Alt 1)
ann_std
# Out:
# 0.27381663717464577

# %% [markdown]
# __Are Return and Risk constant over time? No, of course not! They change over time.__

# %% [markdown]
# __Let´s measure/quantify this with rolling statistics!__

# %%
window = 252 # rolling window 252 trading days (~ 1 Year)

# %%
msft.log_ret.rolling(window = 252)
# Out:
# Rolling [window=252,center=False,axis=0,method=single]

# %%
# Compute the rolling sum of the most recent 252 rows.
msft.log_ret.rolling(window = 252).sum() # Alt 1
# Out:
# Date
# 2014-10-01        NaN
# 2014-10-02        NaN
# 2014-10-03        NaN
# 2014-10-06        NaN
# 2014-10-07        NaN
#                ...
# 2021-05-24   0.312307
# 2021-05-25   0.326676
# 2021-05-26   0.324441
# 2021-05-27   0.317993
# 2021-05-28   0.309329
# Name: log_ret, Length: 1677, dtype: float64

# %%
# compute the rolling mean. it's call also window feature.
# this is the log_return mean of the most recent 252 days.  
roll_mean = msft.log_ret.rolling(window = 252).mean() * 252 # Alt 2
roll_mean
# Out:
# Date
# 2014-10-01        NaN
# 2014-10-02        NaN
# 2014-10-03        NaN
# 2014-10-06        NaN
# 2014-10-07        NaN
#                ...
# 2021-05-24   0.312307
# 2021-05-25   0.326676
# 2021-05-26   0.324441
# 2021-05-27   0.317993
# 2021-05-28   0.309329
# Name: log_ret, Length: 1677, dtype: float64

# %%
roll_mean.iloc[250:]
# Out:
# Date
# 2015-09-29         NaN
# 2015-09-30         NaN
# 2015-10-01   -0.028507
# 2015-10-02   -0.004161
# 2015-10-05    0.011648
#                 ...
# 2021-05-24    0.312307
# 2021-05-25    0.326676
# 2021-05-26    0.324441
# 2021-05-27    0.317993
# 2021-05-28    0.309329
# Name: log_ret, Length: 1427, dtype: float64

# %%
# Plot the rolling mean. 
roll_mean.plot(figsize = (12, 8))
plt.show()

# We can see clearly that the mean return is not stable over time.

# %%
# Calculate the rolling std. 
roll_std = msft.log_ret.rolling(window = 252).std() * np.sqrt(252)
roll_std
# Out:
# Date
# 2014-10-01        NaN
# 2014-10-02        NaN
# 2014-10-03        NaN
# 2014-10-06        NaN
# 2014-10-07        NaN
#                ...
# 2021-05-24   0.279428
# 2021-05-25   0.279185
# 2021-05-26   0.279194
# 2021-05-27   0.279350
# 2021-05-28   0.279208
# Name: log_ret, Length: 1677, dtype: float64

# %%
# then plot
roll_std.plot(figsize = (12, 8))
plt.show()

# %%
# Plot the rolling mean and std 

roll_mean.plot(figsize = (12, 8)) # Plot the rolling mean
roll_std.plot() # Plot rolling std 
plt.show()

# We can see that:
# the more fluctioation, the more std.

# %% [markdown]
# __Take Home__: Be careful, you´ll always find (sub-)periods with __low returns & high risk__ and __high returns & low risk__.

# %% [markdown]
# - Analysis Period must be __sufficiently long__ to reduce impact of random noise. <br>
# - Analysis Period should be __as short as possible__ and should only include the __latest trends / regimes__.
# - Commonly used reporting period: __3 Years / 36 Months__

# %% [markdown]
# __Another Example: Simple Moving Average (Prices) - SMA__

# %%
sma_window = 50

# %%
# Plot the return
msft.Price.plot(figsize = (12, 8))
# Compute the Simple Moving Avarage of 50 days, then plot that. 
msft.Price.rolling(sma_window).mean().plot()
plt.show()

# %% [markdown]
# --------------------------------------------

# %% [markdown]
# ## Short Selling / Short Positions (Part 1)

# %% [markdown]
# What´s the rational behind short selling an instrument? <br>
# __-> making profits/positive returns when prices fall.__

# %% [markdown]
# __Stocks Example:__

# %% [markdown]
# Today an Investor __buys__ the ABC Stock for USD 100. One day later he __sells__ the stock for USD 110. <br>
# __-> Profit: USD 10__ <br>
# ->__Long Position__ (benefit from rising prices):

# %% [markdown]
# Today an Investor __borrows__ the ABC Stock from another Investor and __sells__ it for USD 100. One day later he __buys__ the stock for USD 90 and __returns__ it to the lender.<br>
# __-> Profit: USD 10__  <br>
# ->__Short Position__ (benefit from falling prices):

# %% [markdown]
# In some countries (and for some instruments like stocks) short selling is prohibited. <br>
# Most intuitive/popular use case for short selling: __Currencies (Forex)__

# %% [markdown]
# ## Short Selling / Short Positions (Part 2)

# %% [markdown]
# __EUR/USD__ ("Long Euro" == "Short USD")

# %%
t0 = 1.10 # today price
t1 = 1.25 # tomorow paice

# %% [markdown]
# Today an Investor __buys__ EUR 1 and pays USD 1.10. One day later he __sells__ EUR 1 for USD 1.25 <br>
# __-> Profit: USD 0.15__  <br>
# ->__Long Position Euro__ (benefit from rising EUR prices):

# %%
t1 / t0 - 1 # The EUR appreciates by 13.64% relative to USD (simple return)
# Out:
# 0.13636363636363624

# %% [markdown]
# -> EUR __Long__ Position returns __+13.64%__ (simple return)

# %% [markdown]
# Now another question, <br>
# What return would you expect for the corresponding EUR __Short__ position? That´s a "no brainer": __-13.64%__, right?

# %% [markdown]
# Inverse Rate: __USD/EUR__ ("Short Euro" == "Long USD")

# %%
t0 = 1 / 1.10  
t1 = 1 / 1.25

# %%
print(t0, t1)
# Out:
# 0.9090909090909091 0.8

# %% [markdown]
# Today an Investor __buys__ USD 1 and pays 0.9091 Euro. One day later he __sells__ USD 1 for EUR 0.8 __<br>
# -> Loss: EUR 0.1091__  <br>

# %%
t1 / t0 - 1 # The USD depreciates by 12.0% relative to EUR
# Out:
# -0.11999999999999988

# %% [markdown]
# -> EUR __Short__ Position returns __-12.0%__ (simple return)

# %% [markdown]
# __Take Home: When using simple returns, long position return != short position return * (-1)__ <br>
# __-> Use log returns!__

# %% [markdown]
# ## Short Selling / Short Positions (Part 3)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.6f}'.format
plt.style.use("seaborn-v0_8")

# %%
# Get the close price for 6 instoments.
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                    BA      BTC-USD  EURUSD=X        GC=F       MSFT  \
# Date
# 2014-10-01 124.669998   383.614990  1.262834 1214.599976  45.900002
# 2014-10-02 124.169998   375.071991  1.262419 1214.199951  45.759998
# 2014-10-03 126.360001   359.511993  1.267058 1192.199951  46.090000
# 2014-10-04        NaN   328.865997       NaN         NaN        NaN
# 2014-10-05        NaN   320.510010       NaN         NaN        NaN
# ...               ...          ...       ...         ...        ...
# 2021-05-26 241.369995 39294.199219  1.224909 1901.300049 251.490005
# 2021-05-27 250.699997 38436.968750  1.219260 1895.699951 249.309998
# 2021-05-28 247.020004 35697.605469  1.219319 1902.500000 249.679993
# 2021-05-29        NaN 34616.066406       NaN         NaN        NaN
# 2021-05-30        NaN 35678.128906       NaN         NaN        NaN
#
#                    ^DJI
# Date
# 2014-10-01 16804.710938
# 2014-10-02 16801.050781
# 2014-10-03 17009.689453
# 2014-10-04          NaN
# 2014-10-05          NaN
# ...                 ...
# 2021-05-26 34323.050781
# 2021-05-27 34464.640625
# 2021-05-28 34529.449219
# 2021-05-29          NaN
# 2021-05-30          NaN
#
# [2434 rows x 6 columns]

# %%
# the inverse of EUR->USD, we calculate the USD->EUR
close["USDEUR=X"] = 1/close["EURUSD=X"]

# %%
close
# Out:
#                    BA      BTC-USD  EURUSD=X        GC=F       MSFT  \
# Date
# 2014-10-01 124.669998   383.614990  1.262834 1214.599976  45.900002
# 2014-10-02 124.169998   375.071991  1.262419 1214.199951  45.759998
# 2014-10-03 126.360001   359.511993  1.267058 1192.199951  46.090000
# 2014-10-04        NaN   328.865997       NaN         NaN        NaN
# 2014-10-05        NaN   320.510010       NaN         NaN        NaN
# ...               ...          ...       ...         ...        ...
# 2021-05-26 241.369995 39294.199219  1.224909 1901.300049 251.490005
# 2021-05-27 250.699997 38436.968750  1.219260 1895.699951 249.309998
# 2021-05-28 247.020004 35697.605469  1.219319 1902.500000 249.679993
# 2021-05-29        NaN 34616.066406       NaN         NaN        NaN
# 2021-05-30        NaN 35678.128906       NaN         NaN        NaN
#
#                    ^DJI  USDEUR=X
# Date
# 2014-10-01 16804.710938  0.791870
# 2014-10-02 16801.050781  0.792130
# 2014-10-03 17009.689453  0.789230
# 2014-10-04          NaN       NaN
# 2014-10-05          NaN       NaN
# ...                 ...       ...
# 2021-05-26 34323.050781  0.816387
# 2021-05-27 34464.640625  0.820170
# 2021-05-28 34529.449219  0.820130
# 2021-05-29          NaN       NaN
# 2021-05-30          NaN       NaN
#
# [2434 rows x 7 columns]

# %%
# Store the EUR->USD and the USD->EUR
fx = close[["EURUSD=X", "USDEUR=X"]].dropna().copy()

# %%
# EUR->USD: I want to buy EUR with my USD. 
# USD->EUR: I want to buy USD with my EUR. 
fx
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2014-10-01  1.262834  0.791870
# 2014-10-02  1.262419  0.792130
# 2014-10-03  1.267058  0.789230
# 2014-10-06  1.251361  0.799130
# 2014-10-07  1.264606  0.790760
# ...              ...       ...
# 2021-05-24  1.218324  0.820800
# 2021-05-25  1.221464  0.818690
# 2021-05-26  1.224909  0.816387
# 2021-05-27  1.219260  0.820170
# 2021-05-28  1.219319  0.820130
#
# [1735 rows x 2 columns]

# %%
# Plot the EUR->USD & USD->EUR:
fx.plot(figsize = (12,8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# Its clear that they move in the negative direction.
# It's a negative strong correlation.
# Where the USD rise up, the EUR be weeker, and vica verca. 

# Its PERFECTLY CORRELATED

# %%
# Compute the simple return. 
## Its PERFECTLY CORRELATED
simple_ret = fx.pct_change() # simple returns
simple_ret
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2014-10-01       NaN       NaN
# 2014-10-02 -0.000328  0.000328
# 2014-10-03  0.003674 -0.003661
# 2014-10-06 -0.012389  0.012544
# 2014-10-07  0.010585 -0.010474
# ...              ...       ...
# 2021-05-24 -0.003448  0.003460
# 2021-05-25  0.002577 -0.002571
# 2021-05-26  0.002821 -0.002813
# 2021-05-27 -0.004612  0.004634
# 2021-05-28  0.000049 -0.000049
#
# [1735 rows x 2 columns]

# %%
simple_ret.add(1).prod() - 1 # compound simple returns


# EURUSD=X   -0.034458: over time with long position we lose. 
# USDEUR=X    0.035688: over time with short position we gain.
# Out:
# EURUSD=X   -0.034458
# USDEUR=X    0.035688
# dtype: float64

# %% [markdown]
# __-> For simple returns: long position returns != short position returns * (-1)__

# %%
# Compute the log return
log_ret = np.log(fx / fx.shift()) # log returns
log_ret
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2014-10-01       NaN       NaN
# 2014-10-02 -0.000328  0.000328
# 2014-10-03  0.003668 -0.003668
# 2014-10-06 -0.012466  0.012466
# 2014-10-07  0.010529 -0.010529
# ...              ...       ...
# 2021-05-24 -0.003454  0.003454
# 2021-05-25  0.002574 -0.002574
# 2021-05-26  0.002817 -0.002817
# 2021-05-27 -0.004623  0.004623
# 2021-05-28  0.000049 -0.000049
#
# [1735 rows x 2 columns]

# %%
log_ret.sum() # cumulative log returns
# Out:
# EURUSD=X   -0.035066
# USDEUR=X    0.035066
# dtype: float64

# %% [markdown]
# __-> For log returns: long position returns == short position returns * (-1)__

# %%
norm_fx = log_ret.cumsum().apply(np.exp) # normalized prices (Base 1)
norm_fx
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2014-10-01       NaN       NaN
# 2014-10-02  0.999672  1.000328
# 2014-10-03  1.003345  0.996666
# 2014-10-06  0.990915  1.009168
# 2014-10-07  1.001404  0.998598
# ...              ...       ...
# 2021-05-24  0.964754  1.036534
# 2021-05-25  0.967240  1.033869
# 2021-05-26  0.969969  1.030961
# 2021-05-27  0.965495  1.035738
# 2021-05-28  0.965542  1.035688
#
# [1735 rows x 2 columns]

# %%
norm_fx.iloc[0] = [1, 1]

# %%
norm_fx
# Out:
#             EURUSD=X  USDEUR=X
# Date
# 2014-10-01  1.000000  1.000000
# 2014-10-02  0.999672  1.000328
# 2014-10-03  1.003345  0.996666
# 2014-10-06  0.990915  1.009168
# 2014-10-07  1.001404  0.998598
# ...              ...       ...
# 2021-05-24  0.964754  1.036534
# 2021-05-25  0.967240  1.033869
# 2021-05-26  0.969969  1.030961
# 2021-05-27  0.965495  1.035738
# 2021-05-28  0.965542  1.035688
#
# [1735 rows x 2 columns]

# %%
norm_fx.plot(figsize = (12,8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# ---------------------------------------------

# %% [markdown]
# ## Covariance and Correlation

# %% [markdown]
# Do instruments/assets __move together__ (and to what extent)? <br>
#
# Three cases:
# - unrelated (__no__ relationship/correlation)
# - moving together (__positive__ relationship/correlation)
# - moving in opposite directions (__negative__ relationship/correlation)

# %% [markdown]
# __-> Correlation between instruments/assets play an important role in portfolio management.__

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 124.6700   383.6150    1.2628 1214.6000  45.9000 16804.7109
# 2014-10-02 124.1700   375.0720    1.2624 1214.2000  45.7600 16801.0508
# 2014-10-03 126.3600   359.5120    1.2671 1192.2000  46.0900 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 251.4900 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 249.3100 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 249.6800 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
# Create USD->EUR column.
# Its exactly the inverse of EUR->USD
close["USDEUR=X"] = 1/close["EURUSD=X"]
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI  \
# Date
# 2014-10-01 124.6700   383.6150    1.2628 1214.6000  45.9000 16804.7109
# 2014-10-02 124.1700   375.0720    1.2624 1214.2000  45.7600 16801.0508
# 2014-10-03 126.3600   359.5120    1.2671 1192.2000  46.0900 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 251.4900 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 249.3100 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 249.6800 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
#             USDEUR=X
# Date
# 2014-10-01    0.7919
# 2014-10-02    0.7921
# 2014-10-03    0.7892
# 2014-10-04       NaN
# 2014-10-05       NaN
# ...              ...
# 2021-05-26    0.8164
# 2021-05-27    0.8202
# 2021-05-28    0.8201
# 2021-05-29       NaN
# 2021-05-30       NaN
#
# [2434 rows x 7 columns]

# %%
# Log return of close price. 
returns = close.apply(lambda x: np.log(x.dropna() / x.dropna().shift()))
returns
# Out:
#                 BA  BTC-USD  EURUSD=X    GC=F    MSFT    ^DJI  USDEUR=X
# Date
# 2014-10-01     NaN      NaN       NaN     NaN     NaN     NaN       NaN
# 2014-10-02 -0.0040  -0.0225   -0.0003 -0.0003 -0.0031 -0.0002    0.0003
# 2014-10-03  0.0175  -0.0424    0.0037 -0.0183  0.0072  0.0123   -0.0037
# 2014-10-04     NaN  -0.0891       NaN     NaN     NaN     NaN       NaN
# 2014-10-05     NaN  -0.0257       NaN     NaN     NaN     NaN       NaN
# ...            ...      ...       ...     ...     ...     ...       ...
# 2021-05-26  0.0026   0.0230    0.0028  0.0017 -0.0009  0.0003   -0.0028
# 2021-05-27  0.0379  -0.0221   -0.0046 -0.0029 -0.0087  0.0041    0.0046
# 2021-05-28 -0.0148  -0.0739    0.0000  0.0036  0.0015  0.0019   -0.0000
# 2021-05-29     NaN  -0.0308       NaN     NaN     NaN     NaN       NaN
# 2021-05-30     NaN   0.0302       NaN     NaN     NaN     NaN       NaN
#
# [2434 rows x 7 columns]

# %%
returns.cov() # covariance (hard to interpret)
# Out:
#               BA  BTC-USD  EURUSD=X    GC=F    MSFT    ^DJI  USDEUR=X
# BA        0.0007   0.0001    0.0000  0.0000  0.0002  0.0002   -0.0000
# BTC-USD   0.0001   0.0016   -0.0000  0.0000  0.0001  0.0001    0.0000
# EURUSD=X  0.0000  -0.0000    0.0000  0.0000 -0.0000  0.0000   -0.0000
# GC=F      0.0000   0.0000    0.0000  0.0001 -0.0000 -0.0000   -0.0000
# MSFT      0.0002   0.0001   -0.0000 -0.0000  0.0003  0.0002    0.0000
# ^DJI      0.0002   0.0001    0.0000 -0.0000  0.0002  0.0001   -0.0000
# USDEUR=X -0.0000   0.0000   -0.0000 -0.0000  0.0000 -0.0000    0.0000

# %%
returns.corr() # correlation coefficient (easy to interpret)
# Out:
#               BA  BTC-USD  EURUSD=X    GC=F    MSFT    ^DJI  USDEUR=X
# BA        1.0000   0.1323    0.0347  0.0048  0.4221  0.7253   -0.0347
# BTC-USD   0.1323   1.0000   -0.0163  0.0986  0.1450  0.1604    0.0163
# EURUSD=X  0.0347  -0.0163    1.0000  0.0565 -0.0191  0.0295   -1.0000
# GC=F      0.0048   0.0986    0.0565  1.0000 -0.0008 -0.0121   -0.0565
# MSFT      0.4221   0.1450   -0.0191 -0.0008  1.0000  0.7422    0.0191
# ^DJI      0.7253   0.1604    0.0295 -0.0121  0.7422  1.0000   -0.0295
# USDEUR=X -0.0347   0.0163   -1.0000 -0.0565  0.0191 -0.0295    1.0000

# %% [markdown]
# Three cases:
# - no correlation: __correlation coefficient == 0__
# - moving together: __0 < correlation coefficient <= 1__ (positive)
# - moving in opposite directions: __-1 <= correlation coefficient < 0__ (negative)

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(returns.corr(), cmap = "RdYlBu_r", annot = True, annot_kws={"size":15}, vmin = -1, vmax = 1)
plt.show()

# %% [markdown]
# __Take Home: Similar assets are (highly) positive correlated. Different assets exhibit low/no/negative correlation.__ <br>
# -> In portfolio management it´s beneficial to have assets with low/no/negative correlation (portfolio diversification effect).

# %% [markdown]
# ## Portfolio of Assets and Portfolio Returns

# %%
import pandas as pd
import numpy as np

# %%
prices = pd.DataFrame(data = {"Asset_A": [100, 112], "Asset_B":[100, 104]}, index = [0, 1])
prices
# Out:
#    Asset_A  Asset_B
# 0      100      100
# 1      112      104

# %%
prices["Total"] = prices.Asset_A + prices.Asset_B

# %% [markdown]
# __Surprisingly, that´s incorrect!!!__

# %%
prices
# Out:
#    Asset_A  Asset_B  Total
# 0      100      100    200
# 1      112      104    216

# %%
returns = prices.pct_change() # simple returns
returns
# Out:
#    Asset_A  Asset_B  Total
# 0      NaN      NaN    NaN
# 1   0.1200   0.0400 0.0800

# %%
# correct (portfolio return == weighted average of simple returns)
0.5 * 0.12 + 0.5 * 0.04
# Out:
# 0.08

# %%
# Compute the log return of each asset, and the log return of the total. 
log_returns = np.log(prices / prices.shift()) # log returns
log_returns
# Out:
#    Asset_A  Asset_B  Total
# 0      NaN      NaN    NaN
# 1   0.1133   0.0392 0.0770

# %%
# incorrect (portfolio return != weighted average of log returns)
0.5 * log_returns.iloc[1,0] + 0.5 * log_returns.iloc[1,1]
# Out:
# 0.0762746992301423

# %% [markdown]
# __Take Home: While log returns are time-additive, they are not asset-additive.__ <br>
# (While simple returns are not time-additive, they are asset-additive.)

# %% [markdown]
# ---

# %% [markdown]
# ## Margin Trading & Levered Returns (Part 1)

# %% [markdown]
# __Definition__: "Margin trading refers to the practice of using __borrowed funds__ from a broker to trade a financial asset, which forms the collateral for the loan from the broker." (Investopedia.com)

# %% [markdown]
# In Simple Words: Investors __don´t pay the full price__ but they get the full benefit (less borrowing costs).

# %% [markdown]
# It´s a two edged sword: Leverage __amplifies both gains and losses__. <br> In the event of a loss, the collateral gets reduced and the Investor either posts additional margin or the brokers closes the position.

# %% [markdown]
# __Example__

# %% [markdown]
# A Trader buys a stock (stock price: 100) __on margin (50%)__. After one day the price increases to 110.<br>
# Calculate __unlevered return__ and __levered return__.

# %%
P0 = 100 # price day 1
P1 = 110 # price day 2

leverage = 2 # the lavarage (2x)
margin = P0/2

# %%
margin
# Out:
# 50.0

# %%
# un-leverage return
unlev_return = (P1 - P0) / P0 # simple return
unlev_return
# Out:
# 0.1

# %%
# the leverage return (2x)! 
lev_return = (P1 - P0) / margin # simple return 
lev_return
# Out:
# 0.2

# %%
# this relationship is true for simple returns...
lev_return == unlev_return * leverage
# Out:
# True

# %%
# un-leverage log return 
unlev_return = np.log((P1 - P0) / P0 + 1) # log return
unlev_return
# Out:
# 0.09531017980432493

# %%
# leverage log return
lev_return = np.log((P1 - P0) / margin + 1) # log return
lev_return
# Out:
# 0.1823215567939546

# %%
lev_return == unlev_return * leverage # this relationship does not hold for log returns...
# Out:
# False

# %% [markdown]
# __Take Home: To calculate levered returns, don´t multiply leverage with log returns!__

# %% [markdown]
# ---

# %% [markdown]
# ## Margin Trading & Levered Returns (Part 2)

# %% [markdown]
# __Hypothesis: For (highly) profitable Investment: The more leverage, the better?__

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
#plt.style.use("seaborn-v0_8")

# %%
msft = pd.read_csv("msft.csv", index_col = "Date", parse_dates = ["Date"])
msft
# Out:
#               Price  Returns
# Date
# 2014-10-01  45.9000      NaN
# 2014-10-02  45.7600  -0.0031
# 2014-10-03  46.0900   0.0072
# 2014-10-06  46.0900   0.0000
# 2014-10-07  45.5300  -0.0122
# ...             ...      ...
# 2021-05-24 250.7800   0.0229
# 2021-05-25 251.7200   0.0037
# 2021-05-26 251.4900  -0.0009
# 2021-05-27 249.3100  -0.0087
# 2021-05-28 249.6800   0.0015
#
# [1677 rows x 2 columns]

# %%
# pct_change() -> precentege change. 
# compute the simple return of close 
msft["Simple_Ret"] = msft.Price.pct_change() # simple returns

# %%
leverage = 2

# %% [markdown]
# (Simplified) __Assumptions__:
# - Restore leverage on a daily basis (by buying/selling shares)
# - no trading costs
# - no borrowing costs

# %%
# Compute the leverege return 
# we just multiplied the returns by the leverage ( `mul(leverage)` )
msft["Lev_Returns"] = msft.Returns.mul(leverage) # levered simple returns
msft
# Out:
#               Price  Returns  Simple_Ret  Lev_Returns
# Date
# 2014-10-01  45.9000      NaN         NaN          NaN
# 2014-10-02  45.7600  -0.0031     -0.0031      -0.0061
# 2014-10-03  46.0900   0.0072      0.0072       0.0144
# 2014-10-06  46.0900   0.0000      0.0000       0.0000
# 2014-10-07  45.5300  -0.0122     -0.0122      -0.0243
# ...             ...      ...         ...          ...
# 2021-05-24 250.7800   0.0229      0.0229       0.0458
# 2021-05-25 251.7200   0.0037      0.0037       0.0075
# 2021-05-26 251.4900  -0.0009     -0.0009      -0.0018
# 2021-05-27 249.3100  -0.0087     -0.0087      -0.0173
# 2021-05-28 249.6800   0.0015      0.0015       0.0030
#
# [1677 rows x 4 columns]

# %%
# Its not make sance that the return will be less then -1 (-100%),
# we can loss up to -100%.
# so, where the return < -100%, we set it -100% (-1). 
msft["Lev_Returns"] = np.where(msft["Lev_Returns"] < -1, -1, msft["Lev_Returns"])

# %%
msft
# Out:
#               Price  Returns  Simple_Ret  Lev_Returns
# Date
# 2014-10-01  45.9000      NaN         NaN          NaN
# 2014-10-02  45.7600  -0.0031     -0.0031      -0.0061
# 2014-10-03  46.0900   0.0072      0.0072       0.0144
# 2014-10-06  46.0900   0.0000      0.0000       0.0000
# 2014-10-07  45.5300  -0.0122     -0.0122      -0.0243
# ...             ...      ...         ...          ...
# 2021-05-24 250.7800   0.0229      0.0229       0.0458
# 2021-05-25 251.7200   0.0037      0.0037       0.0075
# 2021-05-26 251.4900  -0.0009     -0.0009      -0.0018
# 2021-05-27 249.3100  -0.0087     -0.0087      -0.0173
# 2021-05-28 249.6800   0.0015      0.0015       0.0030
#
# [1677 rows x 4 columns]

# %%
# calculate the cumulative product of the 
# returns for two financial instruments: "Returns" and "Lev_Returns".  

# add(1) -> it adds 1 to each value in these columns. [1,2,3] -> [2,3,4] 
# cumprod()-> calculates the cumulative product of 
# the modified returns [1,2,3,4] -> [1,2,6,24]

msft[["Returns", "Lev_Returns"]].add(1).cumprod().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()


# We can see clearly that where the leverege gose up, 
# the return higer, and the risk (std - more volatility) also increase!

# %%
# The max of simple return
msft.Simple_Ret.max()
# Out:
# 0.14216888119914373

# %%
# The max of leverage return (2x relative to simple return)
msft.Lev_Returns.max()
# Out:
# 0.2843377623982874

# %%
msft.Simple_Ret.min()
# Out:
# -0.1473903128642552

# %%
msft.Lev_Returns.min()
# Out:
# -0.2947806257285104

# %% [markdown]
# __What happens when leverage greater than...?__

# %%
-1 / msft.Simple_Ret.min()
# Out:
# 6.784706406865346

# %% [markdown]
# __Take Home:__
# 1. With Leverage you can (theoretically) __lose more than the initial Margin__ (in practice: margin call / margin closeout before)
# 2. Even for (highly) profitable instruments: __"The more leverage the better" does not hold__.
# 3. It´s a two edged (__non-symmetrical__) sword: __Leverage amplifies losses more than it amplifies gains__.

# %% [markdown]
# --------------------------------

# %% [markdown]
# __Coding Challenge #7__

# %% [markdown]
# 1. Calculate levered returns for Bitcoin (leverage = 4).
#
# 2. Visualize and compare with unlevered Investment.
#
# 3. Some Traders trade Bitcoin with extremely high leverage (> 100). Do you think this is a good idea (assuming no additional/advanced Risk Management Tools)?

# %% [markdown]
# ---------------------------------------------

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ## Coding Challenge Solutions

# %% [markdown]
# __Coding Challenge #1__

# %% [markdown]
# 1. Load Stock Price Data for General Electric (GE) and another ticker symbol of your choice from 2015-01-02 until 2020-12-31.<br>
# Go to https://finance.yahoo.com/ and get the right ticker symbol. For instruments traded outside the US, you have to add a country/exchange suffix. <br>
# Check the suffix list here https://help.yahoo.com/kb/exchanges-data-providers-yahoo-finance-sln2310.html As an example, the suffix for the National Indian Stock Exchange is .NS -> Ticker Symbol for Reliance is Reliance.NS

# %% [markdown]
# 2. Select Close prices only and create a price chart for GE.

# %% [markdown]
# 3. Normalize the stock prices for GE and the Ticker Symbol of your choice (Base Value: 1) and visualize! What´s the final normalized price for GE on 2020-12-30?

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
#plt.style.use("seaborn-v0_8")

# %%
start = "2015-01-02"
end = "2020-12-31"
symbol = ["GE", "Reliance.NS"]

# %%
df = yf.download(symbol, start, end)
df

# %%
close = df.Close.copy()
close

# %%
close.GE.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
norm = close.div(close.iloc[0]).mul(1)
norm

# %% [markdown]
# -> The final normalized Price is 0.4445.

# %%
norm.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# __Coding Challenge #2__

# %% [markdown]
# 1. Calculate daily returns for Bitcoin.

# %% [markdown]
# 2. Calculate the arithmetic mean return and the standard deviation of returns for Bitcoin.

# %% [markdown]
# 3. Compare Bitcoin with Microsoft (mu = 0.00116, sigma = 0.01726). Does the rule "Higher Risk -> Higher Reward" hold?

# %%
import pandas as pd
pd.options.display.float_format = '{:.4f}'.format

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close

# %%
btc = close["BTC-USD"].dropna().to_frame().copy()
btc

# %%
btc["Returns"] = btc.pct_change(periods = 1)
btc

# %%
btc

# %%
mu = btc.Returns.mean() 
mu

# %%
sigma = btc.Returns.std()
sigma

# %%
mu > 0.00116

# %%
sigma > 0.01726

# %% [markdown]
# Does the rule "Higher Risk -> Higher Reward" hold? -> Yes

# %% [markdown]
# __Coding Challenge #3__

# %% [markdown]
# 1. Calculate Boeing´s Investment Multiple

# %% [markdown]
# 2. Calculate Boeing´s CAGR

# %% [markdown]
# 3. Calculate Boeing´s Geometric Mean Return

# %% [markdown]
# 4. Calculate Boeing´s Investment Multiple with compound daily returns

# %%
import pandas as pd
pd.options.display.float_format = '{:.4f}'.format

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close

# %%
ba = close["BA"].dropna().to_frame().copy()
ba

# %%
ba["Returns"] = ba.pct_change(periods = 1)
ba

# %%
multiple = ba.BA[-1] / ba.BA[0]
multiple

# %%
cagr = (ba.BA[-1]/ba.BA[0])**(1/((ba.index[-1] - ba.index[0]).days / 365.25)) - 1 
cagr

# %%
n = ba.Returns.count()
n

# %%
geo_mean = (1 + ba.Returns).prod()**(1/n) - 1 
geo_mean

# %%
multiple = ba.Returns.add(1).prod()
multiple

# %% [markdown]
# __Coding Challenge #4__

# %% [markdown]
# 1. Calculate daily log returns for Boeing.

# %% [markdown]
# 2. Use Boeing´s log returns to calculate
# - Investment Multiple
# - CAGR (assuming 252 trading days)
# - Normalized Prices (Base = 1)

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
#plt.style.use("seaborn-v0_8")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close

# %%
ba = close["BA"].dropna().to_frame().copy()
ba

# %%
ba["log_ret"] = np.log(ba / ba.shift())
ba

# %%
multiple = np.exp(ba.log_ret.sum())
multiple

# %%
cagr = np.exp(ba.log_ret.mean() * 252) - 1
cagr

# %%
norm = ba.log_ret.cumsum().apply(np.exp)
norm

# %% [markdown]
# __Coding Challenge #5__

# %% [markdown]
# 1. Calculate daily log returns for Boeing.
#
# 2. Use Boeing´s daily log returns to calculate the annualized mean and annualized std (assume 252 trading days per year).
#
# 3. Resample to monthly prices and compare the annualized std (monthly) with the annualized std (daily). Any differences?
#
# 4. Keep working with monthly data and calculate/visualize the rolling 36 months mean return (annualized).

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
#plt.style.use("seaborn-v0_8")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close

# %%
ba = close["BA"].dropna().to_frame().copy()
ba

# %%
ba["log_ret"] = np.log(ba / ba.shift())
ba

# %%
ann_mu = ba.log_ret.mean() * 252 
ann_mu

# %%
ann_std = ba.log_ret.std() * np.sqrt(252) 
ann_std

# %%
monthly = ba.BA.resample("M").last().to_frame()
monthly

# %%
monthly["Returns"] = np.log(monthly / monthly.shift())
monthly

# %%
ann_std = monthly.Returns.std() * np.sqrt(12) 
ann_std

# %% [markdown]
# -> Risk (monthly) slighly lower than Risk (daily)

# %%
window = 36

# %%
roll_mean = monthly.Returns.rolling(window = window).mean() * 12
roll_mean

# %%
roll_mean.plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# __Coding Challenge #6__

# %% [markdown]
# 1. Calculate daily log returns for Boeing.
#
# 2. Calculate the annualized mean and annualized std (assume 252 trading days per year) for a short position in Boeing (ignore Trading and Borrowing Costs).

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
#plt.style.use("seaborn-v0_8")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 124.6700   383.6150    1.2628 1214.6000  45.9000 16804.7109
# 2014-10-02 124.1700   375.0720    1.2624 1214.2000  45.7600 16801.0508
# 2014-10-03 126.3600   359.5120    1.2671 1192.2000  46.0900 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 251.4900 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 249.3100 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 249.6800 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
ba = close["BA"].dropna().to_frame().copy()
ba
# Out:
#                  BA
# Date
# 2014-10-01 124.6700
# 2014-10-02 124.1700
# 2014-10-03 126.3600
# 2014-10-06 126.2600
# 2014-10-07 123.3200
# ...             ...
# 2021-05-24 237.4400
# 2021-05-25 240.7400
# 2021-05-26 241.3700
# 2021-05-27 250.7000
# 2021-05-28 247.0200
#
# [1677 rows x 1 columns]

# %%
ba["log_ret"] = np.log(ba / ba.shift())
ba
# Out:
#                  BA  log_ret
# Date
# 2014-10-01 124.6700      NaN
# 2014-10-02 124.1700  -0.0040
# 2014-10-03 126.3600   0.0175
# 2014-10-06 126.2600  -0.0008
# 2014-10-07 123.3200  -0.0236
# ...             ...      ...
# 2021-05-24 237.4400   0.0111
# 2021-05-25 240.7400   0.0138
# 2021-05-26 241.3700   0.0026
# 2021-05-27 250.7000   0.0379
# 2021-05-28 247.0200  -0.0148
#
# [1677 rows x 2 columns]

# %%
ba["short"] = ba.log_ret * (-1)
ba
# Out:
#                  BA  log_ret   short
# Date
# 2014-10-01 124.6700      NaN     NaN
# 2014-10-02 124.1700  -0.0040  0.0040
# 2014-10-03 126.3600   0.0175 -0.0175
# 2014-10-06 126.2600  -0.0008  0.0008
# 2014-10-07 123.3200  -0.0236  0.0236
# ...             ...      ...     ...
# 2021-05-24 237.4400   0.0111 -0.0111
# 2021-05-25 240.7400   0.0138 -0.0138
# 2021-05-26 241.3700   0.0026 -0.0026
# 2021-05-27 250.7000   0.0379 -0.0379
# 2021-05-28 247.0200  -0.0148  0.0148
#
# [1677 rows x 3 columns]

# %%
ann_mean = ba.short.mean() * 252 # equal to ann_mean of long position * (-1)
ann_mean
# Out:
# -0.10281466040592156

# %%
ann_std = ba.short.std() * np.sqrt(252) # same as ann_std of long position
ann_std
# Out:
# 0.4181796243706362

# %% [markdown]
# __Coding Challenge #7__

# %% [markdown]
# 1. Calculate levered returns for Bitcoin (leverage = 4).
#
# 2. Visualize and compare with unlevered Investment.
#
# 3. Some Traders trade Bitcoin with extremely high leverage (> 100). Do you think this is a good idea (assuming no additional/advanced Risk Management Tools)?

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:.4f}'.format
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8")

# %%
close = pd.read_csv("close.csv", index_col = "Date", parse_dates = ["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 124.6700   383.6150    1.2628 1214.6000  45.9000 16804.7109
# 2014-10-02 124.1700   375.0720    1.2624 1214.2000  45.7600 16801.0508
# 2014-10-03 126.3600   359.5120    1.2671 1192.2000  46.0900 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 251.4900 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 249.3100 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 249.6800 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
btc = close["BTC-USD"].dropna().to_frame().copy()
btc
# Out:
#               BTC-USD
# Date
# 2014-10-01   383.6150
# 2014-10-02   375.0720
# 2014-10-03   359.5120
# 2014-10-04   328.8660
# 2014-10-05   320.5100
# ...               ...
# 2021-05-26 39294.1992
# 2021-05-27 38436.9688
# 2021-05-28 35697.6055
# 2021-05-29 34616.0664
# 2021-05-30 35678.1289
#
# [2434 rows x 1 columns]

# %%
btc["Returns"] = btc.pct_change(periods = 1)
btc
# Out:
#               BTC-USD  Returns
# Date
# 2014-10-01   383.6150      NaN
# 2014-10-02   375.0720  -0.0223
# 2014-10-03   359.5120  -0.0415
# 2014-10-04   328.8660  -0.0852
# 2014-10-05   320.5100  -0.0254
# ...               ...      ...
# 2021-05-26 39294.1992   0.0232
# 2021-05-27 38436.9688  -0.0218
# 2021-05-28 35697.6055  -0.0713
# 2021-05-29 34616.0664  -0.0303
# 2021-05-30 35678.1289   0.0307
#
# [2434 rows x 2 columns]

# %%
leverage = 4

# %%
btc["Lev_Returns"] = btc.Returns.mul(leverage) # levered simple returns
btc
# Out:
#               BTC-USD  Returns  Lev_Returns
# Date
# 2014-10-01   383.6150      NaN          NaN
# 2014-10-02   375.0720  -0.0223      -0.0891
# 2014-10-03   359.5120  -0.0415      -0.1659
# 2014-10-04   328.8660  -0.0852      -0.3410
# 2014-10-05   320.5100  -0.0254      -0.1016
# ...               ...      ...          ...
# 2021-05-26 39294.1992   0.0232       0.0929
# 2021-05-27 38436.9688  -0.0218      -0.0873
# 2021-05-28 35697.6055  -0.0713      -0.2851
# 2021-05-29 34616.0664  -0.0303      -0.1212
# 2021-05-30 35678.1289   0.0307       0.1227
#
# [2434 rows x 3 columns]

# %%
btc["Lev_Returns"] = np.where(btc["Lev_Returns"] < -1, -1, btc["Lev_Returns"])

# %%
btc[["Returns", "Lev_Returns"]].add(1).cumprod().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# -> Trading Bitcoin with (high) leverage requires advanced risk monitoring/management. Otherwise, a complete loss is very likely (sooner or later...).
